# %%
import sys
workdir = '/home/jovyan/workspace'
if not workdir in sys.path:
    sys.path.append(workdir)

# %%
import planetengine

# %%
system = planetengine.tests.testsystems.get_system()

# %%
myvar = planetengine.functions.convert(system.viscosityFn, 'viscosity')

# %%
myvar.update()

# %%
planetengine.quickShow(system.viscosityFn)
# Out:
# Fitted 1 variables to the figure.
# Vanilla{Variable_varName=anon{}}
# <img src='data:image/png;base64,...'>

# %%
planetengine.quickShow(myvar)
# Out:
# Fitted 1 variables to the figure.
# Variable_varName=viscosity{}
# <img src='data:image/png;base64,...'>
