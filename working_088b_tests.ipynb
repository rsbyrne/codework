# %%
import sys
import os
workPath = os.path.abspath('..')
if not workPath in sys.path:
    sys.path.append(workPath)

# %%
import planetengine
import everest

# %%
from planetengine.systems import isovisc

# %%
system = isovisc.build(Ra = 1e4, res = 16, f = 0.9)

# %%
system.hashID
# Out:
# 'grioploiru-drienikwu'

# %%
system.iterate()

# %%
system.store()

# %%
system.iterate()

# %%
system.load(1)

# %%
system.iterate()

# %%
system.store()

# %%
system.store()

# %%
system.iterate()

# %%
system.stored
# Out:
# [[1, [0.0005765427305179195, array([[  0.00000000e+00],
#           [ -1.64060130e+01],
#           [ -3.08897477e+01],
#           [ -4.24840991e+01],
#           [ -5.03312349e+01],
#           [ -5.41073658e+01],
#           [ -5.39952040e+01],
#           [ -5.05910026e+01],
#           [ -4.47648908e+01],
#           [ -3.75030277e+01],
#           [ -2.97583016e+01],
#           [ -2.23287193e+01],
#           [ -1.57743435e+01],
#           [ -1.03766729e+01],
#           [ -6.13896654e+00],
#           [ -2.82785006e+00],
#           [  0.00000000e+00],
#           [  0.00000000e+00],
#           [ -1.62045859e+01],
#           [ -3.05605320e+01],
#           [ -4.19974073e+01],
#           [ -4.97125372e+01],
#           [ -5.33884533e+01],
#           [ -5.32065272e+01],
#           [ -4.97613428e+01],
#           [ -4.39220506e+01],
#           [ -3.66747038e+01],
#           [ -2.89726499e+01],
#           [ -2.16142653e+01],
#           [ -1.51591622e+01],
#           [ -9.88717801e+00],
#           [ -5.79961173e+00],
#           [ -2.66421305e+00],
#           [  0.00000000e+00],
#           [  0.00000000e+00],
#           [ -1.56458751e+01],
#           [ -2.95052157e+01],
#           [ -4.05174596e+01],
#           [ -4.78617044e+01],
#           [ -5.12470991e+01],
#           [ -5.08616646e+01],
#           [ -4.72979708e+01],
#           [ -4.14225060e+01],
#           [ -3.42207961e+01],
#           [ -2.66475290e+01],
#           [ -1.95025901e+01],
#           [ -1.33452063e+01],
#           [ -8.45077947e+00],
#           [ -4.80872032e+00],
#           [ -2.15705896e+00],
#           [  0.00000000e+00],
#           [  0.00000000e+00],
#           [ -1.47576643e+01],
#           [ -2.77817737e+01],
#           [ -3.80842859e+01],
#           [ -4.48404769e+01],
#           [ -4.77618986e+01],
#           [ -4.70468231e+01],
#           [ -4.32902947e+01],
#           [ -3.73566551e+01],
#           [ -3.02307742e+01],
#           [ -2.28695418e+01],
#           [ -1.60754514e+01],
#           [ -1.04060523e+01],
#           [ -6.12476732e+00],
#           [ -3.19643182e+00],
#           [ -1.33198261e+00],
#           [  0.00000000e+00],
#           [  0.00000000e+00],
#           [ -1.35650650e+01],
#           [ -2.54747726e+01],
#           [ -3.47997443e+01],
#           [ -4.07557454e+01],
#           [ -4.30570409e+01],
#           [ -4.19010552e+01],
#           [ -3.78854040e+01],
#           [ -3.18745445e+01],
#           [ -2.48533672e+01],
#           [ -1.77813084e+01],
#           [ -1.14628247e+01],
#           [ -6.44994986e+00],
#           [ -2.98948656e+00],
#           [ -1.02124819e+00],
#           [ -2.21897128e-01],
#           [  0.00000000e+00],
#           [  0.00000000e+00],
#           [ -1.21104711e+01],
#           [ -2.26682865e+01],
#           [ -3.07958313e+01],
#           [ -3.57621313e+01],
#           [ -3.73025240e+01],
#           [ -3.56108193e+01],
#           [ -3.12806529e+01],
#           [ -2.51784549e+01],
#           [ -1.82888654e+01],
#           [ -1.15719455e+01],
#           [ -5.83439917e+00],
#           [ -1.62054484e+00],
#           [  8.38474024e-01],
#           [  1.63208720e+00],
#           [  1.13059016e+00],
#           [  0.00000000e+00],
#           [  0.00000000e+00],
#           [ -1.04493989e+01],
#           [ -1.94653266e+01],
#           [ -2.62244699e+01],
#           [ -3.00511878e+01],
#           [ -3.07124267e+01],
#           [ -2.84086727e+01],
#           [ -2.37165646e+01],
#           [ -1.75173812e+01],
#           [ -1.07816191e+01],
#           [ -4.46963275e+00],
#           [  6.01399860e-01],
#           [  3.90108971e+00],
#           [  5.21242661e+00],
#           [  4.66164395e+00],
#           [  2.67383418e+00],
#           [  0.00000000e+00],
#           [  0.00000000e+00],
#           [ -8.64561557e+00],
#           [ -1.59860619e+01],
#           [ -2.12568897e+01],
#           [ -2.38402741e+01],
#           [ -2.35352688e+01],
#           [ -2.05617169e+01],
#           [ -1.54909222e+01],
#           [ -9.17474075e+00],
#           [ -2.59883201e+00],
#           [  3.25316356e+00],
#           [  7.60146048e+00],
#           [  9.90429005e+00],
#           [  9.96489373e+00],
#           [  7.95182385e+00],
#           [  4.34891377e+00],
#           [  0.00000000e+00],
#           [  0.00000000e+00],
#           [ -6.76823194e+00],
#           [ -1.23624085e+01],
#           [ -1.60802344e+01],
#           [ -1.73649073e+01],
#           [ -1.60485027e+01],
#           [ -1.23577524e+01],
#           [ -6.87947767e+00],
#           [ -4.71871005e-01],
#           [  5.91736314e+00],
#           [  1.13078337e+01],
#           [  1.49001443e+01],
#           [  1.61582979e+01],
#           [  1.49139450e+01],
#           [  1.13769878e+01],
#           [  6.09185016e+00],
#           [  0.00000000e+00],
#           [  0.00000000e+00],
#           [ -4.88915454e+00],
#           [ -8.73267493e+00],
#           [ -1.08915504e+01],
#           [ -1.08714153e+01],
#           [ -8.54064422e+00],
#           [ -4.14450459e+00],
#           [  1.73019247e+00],
#           [  8.27941103e+00],
#           [  1.44718090e+01],
#           [  1.93927746e+01],
#           [  2.22108645e+01],
#           [  2.24207954e+01],
#           [  1.98692377e+01],
#           [  1.48059235e+01],
#           [  7.83605187e+00],
#           [  0.00000000e+00],
#           [  0.00000000e+00],
#           [ -3.08049223e+00],
#           [ -5.23630963e+00],
#           [ -5.89042200e+00],
#           [ -4.60956988e+00],
#           [ -1.29826804e+00],
#           [  3.78686932e+00],
#           [  1.00753732e+01],
#           [  1.67139743e+01],
#           [  2.27141762e+01],
#           [  2.71638230e+01],
#           [  2.92458748e+01],
#           [  2.84472599e+01],
#           [  2.46384162e+01],
#           [  1.81065523e+01],
#           [  9.51481626e+00],
#           [  0.00000000e+00],
#           [  0.00000000e+00],
#           [ -1.41192193e+00],
#           [ -2.00846411e+00],
#           [ -1.27026438e+00],
#           [  1.17975669e+00],
#           [  5.40481841e+00],
#           [  1.11348966e+01],
#           [  1.77833980e+01],
#           [  2.45107614e+01],
#           [  3.03502334e+01],
#           [  3.43543198e+01],
#           [  3.57386499e+01],
#           [  3.40026590e+01],
#           [  2.90339452e+01],
#           [  2.11503015e+01],
#           [  1.10637605e+01],
#           [  0.00000000e+00],
#           [  0.00000000e+00],
#           [  5.19802140e-02],
#           [  8.25716717e-01],
#           [  2.79008377e+00],
#           [  6.27216975e+00],
#           [  1.13034635e+01],
#           [  1.75960674e+01],
#           [  2.45594229e+01],
#           [  3.13661207e+01],
#           [  3.70575404e+01],
#           [  4.06815755e+01],
#           [  4.14499937e+01],
#           [  3.88783669e+01],
#           [  3.28832326e+01],
#           [  2.38160044e+01],
#           [  1.24229008e+01],
#           [  0.00000000e+00],
#           [  0.00000000e+00],
#           [  1.25455222e+00],
#           [  3.15662823e+00],
#           [  6.13225487e+00],
#           [  1.04651934e+01],
#           [  1.61589740e+01],
#           [  2.29126590e+01],
#           [  3.01356505e+01],
#           [  3.70065155e+01],
#           [  4.25731062e+01],
#           [  4.58868163e+01],
#           [  4.61561358e+01],
#           [  4.28960053e+01],
#           [  3.60426768e+01],
#           [  2.59948037e+01],
#           [  1.35374112e+01],
#           [  0.00000000e+00],
#           [  0.00000000e+00],
#           [  2.15057255e+00],
#           [  4.89363088e+00],
#           [  8.62226683e+00],
#           [  1.35881470e+01],
#           [  1.97743423e+01],
#           [  2.68712682e+01],
#           [  3.42877797e+01],
#           [  4.12059123e+01],
#           [  4.66783176e+01],
#           [  4.97606730e+01],
#           [  4.96634489e+01],
#           [  4.59001653e+01],
#           [  3.84062744e+01],
#           [  2.76045770e+01],
#           [  1.43529303e+01],
#           [  0.00000000e+00],
#           [  0.00000000e+00],
#           [  2.70586881e+00],
#           [  5.96365846e+00],
#           [  1.01570499e+01],
#           [  1.55131691e+01],
#           [  2.20033103e+01],
#           [  2.93124131e+01],
#           [  3.68485001e+01],
#           [  4.37955734e+01],
#           [  4.92092786e+01],
#           [  5.21482602e+01],
#           [  5.18260333e+01],
#           [  4.77597884e+01],
#           [  3.98869511e+01],
#           [  2.86239706e+01],
#           [  1.48334970e+01],
#           [  0.00000000e+00],
#           [  0.00000000e+00],
#           [  2.88386696e+00],
#           [  6.32259340e+00],
#           [  1.06733052e+01],
#           [  1.61614858e+01],
#           [  2.27547272e+01],
#           [  3.01360566e+01],
#           [  3.77131588e+01],
#           [  4.46706584e+01],
#           [  5.00651327e+01],
#           [  5.29561158e+01],
#           [  5.25581890e+01],
#           [  4.83907483e+01],
#           [  4.03959899e+01],
#           [  2.89954836e+01],
#           [  1.50483480e+01],
#           [  0.00000000e+00]]), array([[ 1.        ],
#           [ 0.89375255],
#           [ 0.78955868],
#           [ 0.689139  ],
#           [ 0.59406959],
#           [ 0.50560847],
#           [ 0.42465882],
#           [ 0.35175901],
#           [ 0.28709556],
#           [ 0.23053189],
#           [ 0.18164563],
#           [ 0.13976935],
#           [ 0.10403135],
#           [ 0.07339466],
#           [ 0.04669363],
#           [ 0.02266675],
#           [ 0.        ],
#           [ 1.        ],
#           [ 0.89456034],
#           [ 0.79112422],
#           [ 0.69141433],
#           [ 0.59696531],
#           [ 0.50901101],
#           [ 0.42843659],
#           [ 0.35576728],
#           [ 0.29118147],
#           [ 0.23453978],
#           [ 0.18542253],
#           [ 0.14317059],
#           [ 0.10692606],
#           [ 0.07567079],
#           [ 0.04826208],
#           [ 0.02346364],
#           [ 0.        ],
#           [ 1.        ],
#           [ 0.89694175],
#           [ 0.79578381],
#           [ 0.69816398],
#           [ 0.60554654],
#           [ 0.51909138],
#           [ 0.43962736],
#           [ 0.36763986],
#           [ 0.30328317],
#           [ 0.24640964],
#           [ 0.1966076 ],
#           [ 0.15324241],
#           [ 0.11549666],
#           [ 0.08240789],
#           [ 0.05290311],
#           [ 0.02583019],
#           [ 0.        ],
#           [ 1.        ],
#           [ 0.90080345],
#           [ 0.80335338],
#           [ 0.70913344],
#           [ 0.61948621],
#           [ 0.53546327],
#           [ 0.4578022 ],
#           [ 0.38692202],
#           [ 0.32293722],
#           [ 0.2656867 ],
#           [ 0.21477181],
#           [ 0.16959756],
#           [ 0.12941267],
#           [ 0.09334645],
#           [ 0.06044063],
#           [ 0.02967369],
#           [ 0.        ],
#           [ 1.        ],
#           [ 0.90599964],
#           [ 0.81353674],
#           [ 0.72389873],
#           [ 0.63825129],
#           [ 0.55750033],
#           [ 0.48226483],
#           [ 0.41287474],
#           [ 0.34939013],
#           [ 0.2916315 ],
#           [ 0.23921786],
#           [ 0.19160804],
#           [ 0.14814066],
#           [ 0.10806872],
#           [ 0.07058599],
#           [ 0.0348461 ],
#           [ 0.        ],
#           [ 1.        ],
#           [ 0.91233162],
#           [ 0.82594388],
#           [ 0.74189079],
#           [ 0.66112131],
#           [ 0.5843588 ],
#           [ 0.51207843],
#           [ 0.44450366],
#           [ 0.38162773],
#           [ 0.32324882],
#           [ 0.26900815],
#           [ 0.21843016],
#           [ 0.17096335],
#           [ 0.12601005],
#           [ 0.08294898],
#           [ 0.04114864],
#           [ 0.        ],
#           [ 1.        ],
#           [ 0.91955617],
#           [ 0.84009938],
#           [ 0.76241873],
#           [ 0.68721749],
#           [ 0.61500856],
#           [ 0.54609992],
#           [ 0.48059714],
#           [ 0.41841355],
#           [ 0.35932591],
#           [ 0.30300085],
#           [ 0.24903544],
#           [ 0.19700496],
#           [ 0.14648109],
#           [ 0.0970545 ],
#           [ 0.04833922],
#           [ 0.        ],
#           [ 1.        ],
#           [ 0.92739567],
#           [ 0.85546011],
#           [ 0.78469497],
#           [ 0.71553759],
#           [ 0.64827312],
#           [ 0.58302465],
#           [ 0.51976607],
#           [ 0.45833712],
#           [ 0.39848249],
#           [ 0.3398898 ],
#           [ 0.28224895],
#           [ 0.22526519],
#           [ 0.16869532],
#           [ 0.11236072],
#           [ 0.05614162],
#           [ 0.        ],
#           [ 1.        ],
#           [ 0.93554891],
#           [ 0.87143627],
#           [ 0.80786453],
#           [ 0.74499419],
#           [ 0.68287368],
#           [ 0.62143761],
#           [ 0.56051684],
#           [ 0.49986397],
#           [ 0.43920581],
#           [ 0.37825972],
#           [ 0.31679528],
#           [ 0.25465797],
#           [ 0.19179926],
#           [ 0.12827966],
#           [ 0.06425611],
#           [ 0.        ],
#           [ 1.        ],
#           [ 0.94370264],
#           [ 0.88741419],
#           [ 0.83103755],
#           [ 0.77445602],
#           [ 0.71748031],
#           [ 0.65985325],
#           [ 0.60126711],
#           [ 0.54140478],
#           [ 0.47994015],
#           [ 0.41663837],
#           [ 0.35134509],
#           [ 0.28405321],
#           [ 0.21490501],
#           [ 0.14419969],
#           [ 0.07237096],
#           [ 0.        ],
#           [ 1.        ],
#           [ 0.95154355],
#           [ 0.90277984],
#           [ 0.85332346],
#           [ 0.8027908 ],
#           [ 0.75076368],
#           [ 0.69680232],
#           [ 0.6404705 ],
#           [ 0.58135485],
#           [ 0.5191139 ],
#           [ 0.45354123],
#           [ 0.38456868],
#           [ 0.31232014],
#           [ 0.23712405],
#           [ 0.15950892],
#           [ 0.08017442],
#           [ 0.        ],
#           [ 1.        ],
#           [ 0.95877026],
#           [ 0.91694252],
#           [ 0.87386548],
#           [ 0.82890959],
#           [ 0.78144601],
#           [ 0.73086587],
#           [ 0.67660547],
#           [ 0.6181798 ],
#           [ 0.55522812],
#           [ 0.48755936],
#           [ 0.41519038],
#           [ 0.33837149],
#           [ 0.25760131],
#           [ 0.17361853],
#           [ 0.08736664],
#           [ 0.        ],
#           [ 1.        ],
#           [ 0.96510492],
#           [ 0.92935764],
#           [ 0.8918738 ],
#           [ 0.85180809],
#           [ 0.80834603],
#           [ 0.76072874],
#           [ 0.70828376],
#           [ 0.65046331],
#           [ 0.58688661],
#           [ 0.51738363],
#           [ 0.44203641],
#           [ 0.36120752],
#           [ 0.27554879],
#           [ 0.18598508],
#           [ 0.0936711 ],
#           [ 0.        ],
#           [ 1.        ],
#           [ 0.97030399],
#           [ 0.93954789],
#           [ 0.90665571],
#           [ 0.87060438],
#           [ 0.83042651],
#           [ 0.78524061],
#           [ 0.73428588],
#           [ 0.67696184],
#           [ 0.61287124],
#           [ 0.54186341],
#           [ 0.46407384],
#           [ 0.37995325],
#           [ 0.29027802],
#           [ 0.19613149],
#           [ 0.09884478],
#           [ 0.        ],
#           [ 1.        ],
#           [ 0.97416794],
#           [ 0.94712137],
#           [ 0.91764155],
#           [ 0.88457337],
#           [ 0.84683593],
#           [ 0.8034569 ],
#           [ 0.75360967],
#           [ 0.69665439],
#           [ 0.63218151],
#           [ 0.56005526],
#           [ 0.4804521 ],
#           [ 0.393888  ],
#           [ 0.30122742],
#           [ 0.20366829],
#           [ 0.10268553],
#           [ 0.        ],
#           [ 1.        ],
#           [ 0.97654837],
#           [ 0.95178521],
#           [ 0.92440701],
#           [ 0.89317599],
#           [ 0.85694156],
#           [ 0.81467542],
#           [ 0.76551032],
#           [ 0.70878207],
#           [ 0.64407358],
#           [ 0.57125834],
#           [ 0.49053859],
#           [ 0.40247176],
#           [ 0.30797729],
#           [ 0.20831753],
#           [ 0.10504442],
#           [ 0.        ],
#           [ 1.        ],
#           [ 0.9773494 ],
#           [ 0.95335931],
#           [ 0.92669085],
#           [ 0.89608025],
#           [ 0.86035346],
#           [ 0.81846327],
#           [ 0.76952868],
#           [ 0.71287727],
#           [ 0.6480894 ],
#           [ 0.57504164],
#           [ 0.49394494],
#           [ 0.40537102],
#           [ 0.31025905],
#           [ 0.20989525],
#           [ 0.10585607],
#           [ 0.        ]])]],
#  [2, [0.001061159561483508, array([[  0.00000000e+00],
#           [ -2.06328124e+01],
#           [ -3.86354729e+01],
#           [ -5.24124825e+01],
#           [ -6.10251672e+01],
#           [ -6.43293761e+01],
#           [ -6.28937935e+01],
#           [ -5.77706810e+01],
#           [ -5.02275598e+01],
#           [ -4.15107921e+01],
#           [ -3.26762953e+01],
#           [ -2.44950740e+01],
#           [ -1.74235409e+01],
#           [ -1.16208874e+01],
#           [ -6.99667574e+00],
#           [ -3.26138093e+00],
#           [  0.00000000e+00],
#           [  0.00000000e+00],
#           [ -2.03680310e+01],
#           [ -3.82634146e+01],
#           [ -5.18858645e+01],
#           [ -6.03539892e+01],
#           [ -6.35452425e+01],
#           [ -6.20307896e+01],
#           [ -5.68583924e+01],
#           [ -4.92917677e+01],
#           [ -4.05769832e+01],
#           [ -3.17731169e+01],
#           [ -2.36561404e+01],
#           [ -1.66869889e+01],
#           [ -1.10269254e+01],
#           [ -6.58356307e+00],
#           [ -3.06095670e+00],
#           [  0.00000000e+00],
#           [  0.00000000e+00],
#           [ -1.96334117e+01],
#           [ -3.69598347e+01],
#           [ -5.01626632e+01],
#           [ -5.82644072e+01],
#           [ -6.11616081e+01],
#           [ -5.94366808e+01],
#           [ -5.41332199e+01],
#           [ -4.65083015e+01],
#           [ -3.78086513e+01],
#           [ -2.91034867e+01],
#           [ -2.11843385e+01],
#           [ -1.45254436e+01],
#           [ -9.29068264e+00],
#           [ -5.37227821e+00],
#           [ -2.43510285e+00],
#           [  0.00000000e+00],
#           [  0.00000000e+00],
#           [ -1.84954966e+01],
#           [ -3.47801412e+01],
#           [ -4.72081001e+01],
#           [ -5.47414675e+01],
#           [ -5.72085857e+01],
#           [ -5.51731505e+01],
#           [ -4.96745569e+01],
#           [ -4.19677814e+01],
#           [ -3.33045832e+01],
#           [ -2.47715493e+01],
#           [ -1.71843465e+01],
#           [ -1.10337710e+01],
#           [ -6.48108546e+00],
#           [ -3.39610771e+00],
#           [ -1.41145770e+00],
#           [  0.00000000e+00],
#           [  0.00000000e+00],
#           [ -1.70013423e+01],
#           [ -3.18888549e+01],
#           [ -4.31799807e+01],
#           [ -4.98949016e+01],
#           [ -5.17953178e+01],
#           [ -4.93717112e+01],
#           [ -4.36336507e+01],
#           [ -3.58350069e+01],
#           [ -2.72361159e+01],
#           [ -1.89456306e+01],
#           [ -1.18084601e+01],
#           [ -6.33378525e+00],
#           [ -2.68631062e+00],
#           [ -7.22600045e-01],
#           [ -3.10014935e-02],
#           [  0.00000000e+00],
#           [  0.00000000e+00],
#           [ -1.51971237e+01],
#           [ -2.84123145e+01],
#           [ -3.82877036e+01],
#           [ -4.39376551e+01],
#           [ -4.51158026e+01],
#           [ -4.22293648e+01],
#           [ -3.62209950e+01],
#           [ -2.83341213e+01],
#           [ -1.98294403e+01],
#           [ -1.18387905e+01],
#           [ -5.24603527e+00],
#           [ -5.86688297e-01],
#           [  1.95735825e+00],
#           [  2.54502074e+00],
#           [  1.65325897e+00],
#           [  0.00000000e+00],
#           [  0.00000000e+00],
#           [ -1.31437444e+01],
#           [ -2.44708110e+01],
#           [ -3.27335085e+01],
#           [ -3.71294253e+01],
#           [ -3.74370466e+01],
#           [ -3.40127059e+01],
#           [ -2.77038861e+01],
#           [ -1.97394972e+01],
#           [ -1.13500788e+01],
#           [ -3.70461877e+00],
#           [  2.26562027e+00],
#           [  5.99348119e+00],
#           [  7.27010350e+00],
#           [  6.27986184e+00],
#           [  3.57713732e+00],
#           [  0.00000000e+00],
#           [  0.00000000e+00],
#           [ -1.09158778e+01],
#           [ -2.02014159e+01],
#           [ -2.67208115e+01],
#           [ -2.97424174e+01],
#           [ -2.90665344e+01],
#           [ -2.50360050e+01],
#           [ -1.84219039e+01],
#           [ -1.03638779e+01],
#           [ -2.09838464e+00],
#           [  5.14084253e+00],
#           [  1.04373141e+01],
#           [  1.31486627e+01],
#           [  1.30434365e+01],
#           [  1.03378126e+01],
#           [  5.66737065e+00],
#           [  0.00000000e+00],
#           [  0.00000000e+00],
#           [ -8.59691783e+00],
#           [ -1.57585611e+01],
#           [ -2.04661950e+01],
#           [ -2.20568113e+01],
#           [ -2.03406049e+01],
#           [ -1.56305304e+01],
#           [ -8.68005666e+00],
#           [ -5.67110143e-01],
#           [  7.51732727e+00],
#           [  1.43584258e+01],
#           [  1.89480777e+01],
#           [  2.05926342e+01],
#           [  1.90498508e+01],
#           [  1.45618582e+01],
#           [  7.84397830e+00],
#           [  0.00000000e+00],
#           [  0.00000000e+00],
#           [ -6.27469271e+00],
#           [ -1.13074349e+01],
#           [ -1.41987066e+01],
#           [ -1.43577893e+01],
#           [ -1.16095342e+01],
#           [ -6.24016803e+00],
#           [  1.05157911e+00],
#           [  9.29516579e+00],
#           [  1.71780342e+01],
#           [  2.35915949e+01],
#           [  2.74418110e+01],
#           [  2.80182060e+01],
#           [  2.50478168e+01],
#           [  1.87860885e+01],
#           [  1.00228592e+01],
#           [  0.00000000e+00],
#           [  0.00000000e+00],
#           [ -4.03769809e+00],
#           [ -7.01601658e+00],
#           [ -8.15061845e+00],
#           [ -6.92177315e+00],
#           [ -3.16958381e+00],
#           [  2.85652297e+00],
#           [  1.05266155e+01],
#           [  1.88163609e+01],
#           [  2.64783837e+01],
#           [  3.24211312e+01],
#           [  3.55573206e+01],
#           [  3.51140145e+01],
#           [  3.07891612e+01],
#           [  2.28400375e+01],
#           [  1.21184059e+01],
#           [  0.00000000e+00],
#           [  0.00000000e+00],
#           [ -1.97149901e+00],
#           [ -3.04730565e+00],
#           [ -2.54774701e+00],
#           [ -1.78768142e-02],
#           [  4.68653394e+00],
#           [  1.13363525e+01],
#           [  1.93125466e+01],
#           [  2.76321957e+01],
#           [  3.51163202e+01],
#           [  4.05986418e+01],
#           [  4.30217498e+01],
#           [  4.16084197e+01],
#           [  3.60366263e+01],
#           [  2.65543588e+01],
#           [  1.40458042e+01],
#           [  0.00000000e+00],
#           [  0.00000000e+00],
#           [ -1.55178970e-01],
#           [  4.47431368e-01],
#           [  2.39656863e+00],
#           [  6.08659452e+00],
#           [  1.16372914e+01],
#           [  1.88223879e+01],
#           [  2.70496885e+01],
#           [  3.53979730e+01],
#           [  4.27249841e+01],
#           [  4.78242715e+01],
#           [  4.96056537e+01],
#           [  4.72938259e+01],
#           [  4.05917379e+01],
#           [  2.97705629e+01],
#           [  1.57226255e+01],
#           [  0.00000000e+00],
#           [  0.00000000e+00],
#           [  1.34206160e+00],
#           [  3.33326918e+00],
#           [  6.48444478e+00],
#           [  1.11344278e+01],
#           [  1.73779375e+01],
#           [  2.49949098e+01],
#           [  3.34272967e+01],
#           [  4.18001672e+01],
#           [  4.89975314e+01],
#           [  5.37987486e+01],
#           [  5.50727955e+01],
#           [  5.20081460e+01],
#           [  4.43218644e+01],
#           [  3.23614053e+01],
#           [  1.70701263e+01],
#           [  0.00000000e+00],
#           [  0.00000000e+00],
#           [  2.46319543e+00],
#           [  5.49197374e+00],
#           [  9.53838866e+00],
#           [  1.49013072e+01],
#           [  2.16578790e+01],
#           [  2.95959805e+01],
#           [  3.81835739e+01],
#           [  4.65762803e+01],
#           [  5.36784255e+01],
#           [  5.82689266e+01],
#           [  5.91920654e+01],
#           [  5.55935780e+01],
#           [  4.71577686e+01],
#           [  3.42732325e+01],
#           [  1.80253062e+01],
#           [  0.00000000e+00],
#           [  0.00000000e+00],
#           [  3.15783129e+00],
#           [  6.82039758e+00],
#           [  1.14182354e+01],
#           [  1.72213031e+01],
#           [  2.42960054e+01],
#           [  3.24350358e+01],
#           [  4.11211705e+01],
#           [  4.95277014e+01],
#           [  5.65724919e+01],
#           [  6.10385912e+01],
#           [  6.17623356e+01],
#           [  5.78691307e+01],
#           [  4.90116569e+01],
#           [  3.55473427e+01],
#           [  1.86009985e+01],
#           [  0.00000000e+00],
#           [  0.00000000e+00],
#           [  3.37833162e+00],
#           [  7.26133236e+00],
#           [  1.20472967e+01],
#           [  1.80002866e+01],
#           [  2.51837854e+01],
#           [  3.33923366e+01],
#           [  4.21135825e+01],
#           [  5.05266348e+01],
#           [  5.75539802e+01],
#           [  6.19805747e+01],
#           [  6.26416229e+01],
#           [  5.86592450e+01],
#           [  4.96817002e+01],
#           [  3.60584425e+01],
#           [  1.89018584e+01],
#           [  0.00000000e+00]]), array([[ 1.        ],
#           [ 0.88477773],
#           [ 0.77271214],
#           [ 0.66614476],
#           [ 0.567087  ],
#           [ 0.47691025],
#           [ 0.39633563],
#           [ 0.32550206],
#           [ 0.26407809],
#           [ 0.21138618],
#           [ 0.1665172 ],
#           [ 0.12842355],
#           [ 0.09598723],
#           [ 0.06806446],
#           [ 0.04351075],
#           [ 0.02119128],
#           [ 0.        ],
#           [ 1.        ],
#           [ 0.88569849],
#           [ 0.7744476 ],
#           [ 0.66866562],
#           [ 0.57029527],
#           [ 0.48067699],
#           [ 0.40051362],
#           [ 0.32993242],
#           [ 0.26859498],
#           [ 0.21582105],
#           [ 0.17070331],
#           [ 0.13220119],
#           [ 0.09920947],
#           [ 0.07060313],
#           [ 0.04526154],
#           [ 0.02207638],
#           [ 0.        ],
#           [ 1.        ],
#           [ 0.88839328],
#           [ 0.77967877],
#           [ 0.67619143],
#           [ 0.57983129],
#           [ 0.4918538 ],
#           [ 0.41290114],
#           [ 0.34306223],
#           [ 0.2819768 ],
#           [ 0.22895629],
#           [ 0.18309866],
#           [ 0.14338363],
#           [ 0.10874337],
#           [ 0.07810898],
#           [ 0.05043616],
#           [ 0.02471747],
#           [ 0.        ],
#           [ 1.        ],
#           [ 0.89274593],
#           [ 0.7881941 ],
#           [ 0.68846637],
#           [ 0.59535667],
#           [ 0.51002804],
#           [ 0.43303344],
#           [ 0.36439585],
#           [ 0.30371625],
#           [ 0.25029155],
#           [ 0.20322798],
#           [ 0.16153844],
#           [ 0.12421762],
#           [ 0.09029195],
#           [ 0.0588432 ],
#           [ 0.02900893],
#           [ 0.        ],
#           [ 1.        ],
#           [ 0.89859314],
#           [ 0.79963705],
#           [ 0.70500359],
#           [ 0.61628587],
#           [ 0.5345168 ],
#           [ 0.46014867],
#           [ 0.39312199],
#           [ 0.33298353],
#           [ 0.27900978],
#           [ 0.23031862],
#           [ 0.18596921],
#           [ 0.14504306],
#           [ 0.10669343],
#           [ 0.07016344],
#           [ 0.03478482],
#           [ 0.        ],
#           [ 1.        ],
#           [ 0.90571476],
#           [ 0.81356662],
#           [ 0.72515127],
#           [ 0.64180938],
#           [ 0.56438814],
#           [ 0.4932171 ],
#           [ 0.42814744],
#           [ 0.36866118],
#           [ 0.31401244],
#           [ 0.26333553],
#           [ 0.21574527],
#           [ 0.17042852],
#           [ 0.1266875 ],
#           [ 0.08396113],
#           [ 0.04182319],
#           [ 0.        ],
#           [ 1.        ],
#           [ 0.91383935],
#           [ 0.82945329],
#           [ 0.74813272],
#           [ 0.67093907],
#           [ 0.59849537],
#           [ 0.53097469],
#           [ 0.46813753],
#           [ 0.4093859 ],
#           [ 0.35396322],
#           [ 0.30102016],
#           [ 0.24973014],
#           [ 0.1994025 ],
#           [ 0.14950571],
#           [ 0.09970572],
#           [ 0.04985389],
#           [ 0.        ],
#           [ 1.        ],
#           [ 0.92265576],
#           [ 0.84669158],
#           [ 0.77306957],
#           [ 0.70255406],
#           [ 0.63552726],
#           [ 0.57197594],
#           [ 0.5115487 ],
#           [ 0.45360275],
#           [ 0.39734431],
#           [ 0.34192374],
#           [ 0.2866199 ],
#           [ 0.23085111],
#           [ 0.17427043],
#           [ 0.11679245],
#           [ 0.05856865],
#           [ 0.        ],
#           [ 1.        ],
#           [ 0.93182581],
#           [ 0.86462232],
#           [ 0.79900902],
#           [ 0.73544198],
#           [ 0.67405629],
#           [ 0.61465582],
#           [ 0.55674664],
#           [ 0.49961222],
#           [ 0.44246114],
#           [ 0.38447888],
#           [ 0.32499699],
#           [ 0.26356303],
#           [ 0.20002898],
#           [ 0.13456486],
#           [ 0.06763287],
#           [ 0.        ],
#           [ 1.        ],
#           [ 0.94099755],
#           [ 0.8825583 ],
#           [ 0.82495797],
#           [ 0.76834277],
#           [ 0.71259775],
#           [ 0.65733696],
#           [ 0.60194115],
#           [ 0.54566325],
#           [ 0.48760917],
#           [ 0.42705385],
#           [ 0.36337635],
#           [ 0.29627501],
#           [ 0.22578879],
#           [ 0.15233932],
#           [ 0.07669832],
#           [ 0.        ],
#           [ 1.        ],
#           [ 0.94981875],
#           [ 0.899811  ],
#           [ 0.8499212 ],
#           [ 0.79999666],
#           [ 0.74968108],
#           [ 0.69841207],
#           [ 0.64546253],
#           [ 0.58996415],
#           [ 0.53103367],
#           [ 0.46797917],
#           [ 0.40027104],
#           [ 0.32772157],
#           [ 0.25055462],
#           [ 0.16943063],
#           [ 0.08541633],
#           [ 0.        ],
#           [ 1.        ],
#           [ 0.95795043],
#           [ 0.91571747],
#           [ 0.87294034],
#           [ 0.82919112],
#           [ 0.78389123],
#           [ 0.73631084],
#           [ 0.68559413],
#           [ 0.63081447],
#           [ 0.57109122],
#           [ 0.50572109],
#           [ 0.43427469],
#           [ 0.35669269],
#           [ 0.27336846],
#           [ 0.18517777],
#           [ 0.0934509 ],
#           [ 0.        ],
#           [ 1.        ],
#           [ 0.96507992],
#           [ 0.92966613],
#           [ 0.89313057],
#           [ 0.85480272],
#           [ 0.81390476],
#           [ 0.76955324],
#           [ 0.72078908],
#           [ 0.66664081],
#           [ 0.60621859],
#           [ 0.53882934],
#           [ 0.46409996],
#           [ 0.38208777],
#           [ 0.29335239],
#           [ 0.19896956],
#           [ 0.100491  ],
#           [ 0.        ],
#           [ 1.        ],
#           [ 0.97093317],
#           [ 0.94112045],
#           [ 0.90971284],
#           [ 0.87583815],
#           [ 0.83855279],
#           [ 0.79684902],
#           [ 0.74968771],
#           [ 0.69605736],
#           [ 0.63505957],
#           [ 0.56601806],
#           [ 0.48860246],
#           [ 0.40294932],
#           [ 0.30975103],
#           [ 0.21027169],
#           [ 0.10626125],
#           [ 0.        ],
#           [ 1.        ],
#           [ 0.97528589],
#           [ 0.94963789],
#           [ 0.92204203],
#           [ 0.8914766 ],
#           [ 0.8568753 ],
#           [ 0.81713938],
#           [ 0.77117009],
#           [ 0.71792476],
#           [ 0.6564988 ],
#           [ 0.58623174],
#           [ 0.50682871],
#           [ 0.41848079],
#           [ 0.32196031],
#           [ 0.2186618 ],
#           [ 0.11053105],
#           [ 0.        ],
#           [ 1.        ],
#           [ 0.97796919],
#           [ 0.95488289],
#           [ 0.92963488],
#           [ 0.90110783],
#           [ 0.86816027],
#           [ 0.82963735],
#           [ 0.78440303],
#           [ 0.73139508],
#           [ 0.66970539],
#           [ 0.59868447],
#           [ 0.51806201],
#           [ 0.42806654],
#           [ 0.32951817],
#           [ 0.22386678],
#           [ 0.11314588],
#           [ 0.        ],
#           [ 1.        ],
#           [ 0.97886678],
#           [ 0.95665081],
#           [ 0.93219625],
#           [ 0.90435793],
#           [ 0.87196936],
#           [ 0.83385673],
#           [ 0.78887137],
#           [ 0.73594438],
#           [ 0.67416642],
#           [ 0.60289177],
#           [ 0.52185883],
#           [ 0.43131014],
#           [ 0.33208564],
#           [ 0.22565837],
#           [ 0.11408249],
#           [ 0.        ]])]]]

# %%
import os
if os.path.exists('../test.frm'):
    os.remove('../test.frm')
system.anchor('test', '..')

# %%
system.save()

# %%
system2 = isovisc.build()

# %%
system2 is system
# Out:
# False

# %%
system.clear()

# %%
system.stored
# Out:
# []

# %%
system.counts_disk
# Out:
# [1, 2]

# %%
system.store()

# %%
system.counts_stored
# Out:
# [3]

# %%
system.save()

# %%
system.counts_stored
# Out:
# []

# %%
system.counts_disk
# Out:
# [1, 2, 3]

# %%
system.load(1)

# %%
system.store()

# %%
system.save()

# %%
system.counts_disk
# Out:
# [1, 2, 3]

# %%
system.constructor

# %%
from everest.builts import load
system_loaded = load(system.hashID, 'test', '..')

# %%
system_loaded is system
# Out:
# True

# %%
system.hashID
# Out:
# 'grioploiru-drienikwu'

# %%
del system
del system_loaded

# %%
del everest.builts.BUILTS['grioploiru-drienikwu']

# %%
everest.builts.BUILTS
# Out:
# {'jisheitwo-fliofiiplo': <weakref at 0x7f02d6782728; to 'Constructor' at 0x7f02d6780320>,
#  'likruukre-gluofioce': <weakref at 0x7f02d64fdd18; to 'Isovisc' at 0x7f02d6501e80>,
#  'ofloupoasmo-idreavuasne': <weakref at 0x7f02d6782188; to 'Constructor' at 0x7f02d6779908>,
#  'udweekleosfi-efookausle': <weakref at 0x7f02d6782048; to 'Sinusoidal' at 0x7f02d6780048>}

# %%
import h5py
myfile = h5py.File('../test.frm')
print(myfile.keys())
myfile.close()
# Out:
# <KeysViewHDF5 ['grioploiru-drienikwu', 'jisheitwo-fliofiiplo', 'ofloupoasmo-idreavuasne', 'udweekleosfi-efookausle']>

# %%
from everest.builts import load
system_loaded = load('grioploiru-drienikwu', 'test', '..')

# %%
system_loaded.hashID
# Out:
# 'grioploiru-drienikwu'

# %%
system_loaded.constructor

# %%
new_system = system_loaded.constructor(Ra = 1e6, f = 0.7)

# %%
new_system.hashID
# Out:
# 'imoismizo-amuteewi'

# %%
system_loaded.inputs
# Out:
# {'Ra': 10000.0,
#  '_initial_temperatureField': <yhjuekwefqoyeapj.py.Sinusoidal at 0x7f02d6780048>,
#  'aspect': 1.0,
#  'f': 0.9,
#  'res': 16,
#  'urey': 0.0}

# %%
new_system.inputs
# Out:
# {'Ra': 1000000.0, 'f': 0.7}
