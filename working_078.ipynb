# %%
import sys
import os
workPath = os.path.abspath('..')
if not workPath in sys.path:
    sys.path.append(workPath)

# %%
import planetengine

# %%
from everest.window import Fetch, Reader
from everest import frame
from everest.built import Built
from everest import built

# %%
outputPath = '../out'
frameName = 'dev'

# %%
system = planetengine.systems.isovisc.build(res = 4, Ra = 1e4)

# %%
system.anchor(frameName, outputPath)

# %%
system.store()
system.save()
system.iterate(2)
system.store()
system.save()

# %%
load_system = built.load(system.hashID, frameName, outputPath)

# %%
load_system

# %%
planetengine.quickShow(load_system.locals.temperatureField)
# Out:
# Variable{8777185890806}
# <img src='data:image/png;base64,...'>

# %%
system.counts_captured

# %%
system.load(0)

# %%
system.count()

# %%
system.modeltime()

# %%
system.load(2)

# %%
system.count()

# %%
system.modeltime()

# %%
system.iterate(100)

# %%
system.store()

# %%
system.save()

# %%
planetengine.quickShow(system.locals.temperatureField)

# %%
system.load(2)

# %%
planetengine.quickShow(system.locals.temperatureField)
