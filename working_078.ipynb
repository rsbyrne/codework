# %%
import sys
import os
workPath = os.path.abspath('..')
if not workPath in sys.path:
    sys.path.append(workPath)

# %%
import planetengine

# %%
from everest.window import Fetch, Reader
from everest import frame
from everest.built import Built

# %%
outputPath = '../out'
frameName = 'dev'

# %%
import h5py

# %%
myfile = h5py.File(os.path.join(outputPath, frameName) + '.frm')

# %%
myfile.keys
# Out:
# <KeysViewHDF5 ['esfeosteiplo-dwiuglietru', 'uvospiokre-kroemouke']>

# %%
myfile['esfeosteiplo-dwiuglietru'][]
# Out:
# <HDF5 dataset "_counts_": shape (1,), type "<i8">

# %%
system = planetengine.systems.isovisc.build(res = 4, Ra = 1e4)

# %%
system.anchor(frameName, outputPath)

# %%
system.store()
system.save()
system.iterate(2)
system.store()
system.save()

# %%
system.counts_captured
# Out:
# [0, 2]

# %%
system.load(0)

# %%
system.count()
# Out:
# 0

# %%
system.modeltime()
# Out:
# 0.0

# %%
system.load(2)

# %%
system.count()
# Out:
# 2

# %%
system.modeltime()
# Out:
# 0.0033253342436866855

# %%
system.iterate(100)

# %%
system.store()

# %%
system.save()

# %%
planetengine.quickShow(system.locals.temperatureField)
# Out:
# Variable{8766704860655}
# <img src='data:image/png;base64,...'>

# %%
system.load(2)

# %%
planetengine.quickShow(system.locals.temperatureField)
# Out:
# Variable{8766704860655}
# <img src='data:image/png;base64,...'>
