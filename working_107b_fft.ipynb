# %%
import planetengine
from planetengine import analysis as pan
from matplotlib import pyplot as plt
import numpy as np
import scipy as sp

# %%
reader = planetengine.Reader('iso', 'workspace/tests_190313')

# %%
chrons = reader['raagteust-puosmkleis', 'outputs', 'chron']
Nus = reader['raagteust-puosmkleis', 'outputs', 'Nu']

# %%
ichrons, iNus = pan.time_smooth(chrons, Nus, 0.5, kind = 'cubic')

# %%
plt.plot(ichrons, iNus)

# %%
plt.plot(iNus)

# %%
len(iNus[None: None])
# Out:
# 986

# %%
plt.plot(*pan.fft(iNus, ichrons))

# %%
plt.plot(*pan.fft(iNus[500:], ichrons))

# %%
# plt.plot(np.log10(freqs), np.log10(fft))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-8-18e0203ebfc9> in <module>
# ----> 1 plt.plot(np.log10(freqs), np.log10(fft))
#
# NameError: name 'freqs' is not defined

# %%
# data = iNus
# av = np.average(data)
# norm = (data - av) / av
# power = np.abs(np.fft.rfft(norm)).real
# freqScale = ichrons[-1] / len(iNus)
# freq = np.fft.rfftfreq(norm.size, 1. / (2. * power.size)) * freqScale

# %%
# plt.plot(freq, sp)

# %%
# chrons = reader['raagteust-puosmkleis', 'outputs', 'chron']
# rasters = reader['raagteust-puosmkleis', 'outputs', 'raster']

# %%
# animated = planetengine.visualisation.raster.animate(rasters, chrons)

# %%
# from IPython.display import Video
# Video(animated, embed = True)
