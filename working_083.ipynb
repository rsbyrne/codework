# %%
import sys
import os
workPath = os.path.abspath('..')
if not workPath in sys.path:
    sys.path.append(workPath)

# %%
import planetengine

# %%
system = planetengine.systems.MS98.build(res = 32, Ra = 4e5, f = 0.54)

# %%
planetengine.quickShow(system.locals.temperatureField, system.locals.mesh)
# Out:
# Variable{-9223363284867424277}
# <img src='data:image/png;base64,...'>

# %%
system.iterate(10)

# %%
planetengine.quickShow(system.locals.temperatureField, system.locals.mesh)
# Out:
# Variable{-9223363284867424277}
# <img src='data:image/png;base64,...'>

# %%
planetengine.quickShow(system.locals.temperatureField, system.locals.mesh)

# %%
system.store()

# %%
system.stored
# Out:
# [[10, [0.0015369085204898273, array([[ 0.        ],
#           [-2.89977947],
#           [-4.9788655 ],
#           ...,
#           [-1.08404814],
#           [-0.58503975],
#           [ 0.        ]]), array([[ 1.        ],
#           [ 0.94383827],
#           [ 0.88993231],
#           ...,
#           [ 0.09976108],
#           [ 0.04976645],
#           [ 0.        ]])]]]

# %%
outputPath = '../out'
frameName = 'dev'

# %%
system.anchor(frameName, outputPath)

# %%
system.save()

# %%
system.hashID
# Out:
# 'atiepheegli-ogailawe'

# %%
system2 = planetengine.systems.MS98.build(res = 32, Ra = 4e5, f = 0.54)

# %%
system2.anchor(frameName, outputPath)

# %%
system2.load(10)

# %%
planetengine.quickShow(system.locals.temperatureField)
# Out:
# Variable{-9223363284867424277}
# <img src='data:image/png;base64,...'>

# %%
system2.hashID == system.hashID
# Out:
# True

# %%
planetengine.quickShow(system2.locals.temperatureField)
# Out:
# Variable{8751973268537}
# <img src='data:image/png;base64,...'>

# %%
system2 = system.load()
