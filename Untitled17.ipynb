# %%
import sys
import os
workPath = os.path.abspath('..')
if not workPath in sys.path:
    sys.path.append(workPath)

# %%
import planetengine

# %%
from planetengine.systems.isovisc import Isovisc

# %%
system = Isovisc()

# %%
from planetengine import functions

# %%
dir(functions)
# Out:
# ['__builtins__',
#  '__cached__',
#  '__doc__',
#  '__file__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__path__',
#  '__spec__',
#  '_basetypes',
#  '_constant',
#  '_construct',
#  '_convert',
#  '_function',
#  '_parameter',
#  '_planetvar',
#  '_reduction',
#  '_shape',
#  '_variable',
#  'component',
#  'convert',
#  'gradient',
#  'operations',
#  'projection',
#  'vanilla']

# %%
mygrad = functions.gradient.ang(system.locals.temperatureField)
# Out:
# Old object found - reusing.
# Old object found - reusing.

# %%
mygrad = functions.gradient.ang(mygrad)

# %%
from planetengine import quickShow

# %%
quickShow(mygrad)
# Out:
# Component_component=ang{Gradient{Projection{Component_component=ang{Gradient{Variable{8728846255389}}}}}}
# <img src='data:image/png;base64,...'>

# %%
velocityField = system.locals.velocityField

# %%
from underworld import function as fn

# %%
tensor = fn.tensor.symmetric(velocityField.fn_gradient)

# %%
quickShow(tensor)
# Out:
# <img src='data:image/png;base64,...'>

# %%
mydata = tensor.evaluate(velocityField.mesh)

# %%
mydata
# Out:
# array([[ 160128.44461612, -164706.88719636, -108809.1619524 ],
#        [ 266022.80808982,  -70212.45724806, -272990.34104335],
#        [ 263173.39535733,  -67106.35968872, -271147.48201991],
#        ...,
#        [-291648.88036755,  -69873.12335956,   85806.8615911 ],
#        [-292160.79548873,  -69234.61011604,   85483.2676949 ],
#        [ 107677.20523019, -114106.25799113,   74177.13091399]])

# %%
mydata[:,:1]
# Out:
# array([[ 160128.44461612],
#        [ 266022.80808982],
#        [ 263173.39535733],
#        ...,
#        [-291648.88036755],
#        [-292160.79548873],
#        [ 107677.20523019]])

# %%
a = 1, 2

# %%
a
# Out:
# (1, 2)

# %%
mydata.__getitem__((slice(-1), slice(1)))
# Out:
# array([[ 160128.44461612],
#        [ 266022.80808982],
#        [ 263173.39535733],
#        ...,
#        [-291361.39357097],
#        [-291648.88036755],
#        [-292160.79548873]])

# %%
mymesh = velocityField.mesh

# %%
dir(mymesh)
# Out:
# ['_SPR',
#  '_Stg_Class_Delete',
#  '_Stg_Class_Unlock',
#  '__abstractmethods__',
#  '__class__',
#  '__del__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__signature__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  '_abc_cache',
#  '_abc_negative_cache',
#  '_abc_negative_cache_version',
#  '_abc_registry',
#  '_add_to_stg_dict',
#  '_angularExtent',
#  '_arr',
#  '_c0',
#  '_c1',
#  '_centroid',
#  '_cself',
#  '_delSelf',
#  '_dim',
#  '_e1',
#  '_e2',
#  '_elementRes',
#  '_elementType',
#  '_elementTypes',
#  '_fn_r_theta',
#  '_fn_unitvec_radial',
#  '_fn_unitvec_tangent',
#  '_gen',
#  '_generator',
#  '_get_iterator',
#  '_id',
#  '_maxCoord',
#  '_mesh',
#  '_meshGenerator',
# ...

# %%
dir(velocityField)
# Out:
# ['_Stg_Class_Delete',
#  '_Stg_Class_Unlock',
#  '__abstractmethods__',
#  '__add__',
#  '__and__',
#  '__class__',
#  '__del__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__mul__',
#  '__ne__',
#  '__neg__',
#  '__new__',
#  '__or__',
#  '__pow__',
#  '__radd__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__rmul__',
#  '__rsub__',
#  '__rtruediv__',
#  '__setattr__',
#  '__signature__',
#  '__sizeof__',
#  '__str__',
#  '__sub__',
#  '__subclasshook__',
#  '__truediv__',
#  '__weakref__',
#  '__xor__',
#  '_abc_cache',
#  '_abc_negative_cache',
#  '_abc_negative_cache_version',
#  '_abc_registry',
#  '_add_to_stg_dict',
#  '_cmeshvariable',
#  '_cself',
#  '_dataType',
#  '_delSelf',
#  '_doflayout',
#  '_evaluate_data_convert_to_ndarray',
#  '_fn_gradient',
#  '_fncself',
# ...

# %%
mydata
# Out:
# array([[ 160128.44461612],
#        [ 266022.80808982],
#        [ 263173.39535733],
#        ...,
#        [-291648.88036755],
#        [-292160.79548873],
#        [ 107677.20523019]])

# %%
mydata = mydata[:,0].reshape(mydata.shape[0], 1)

# %%
mydata
# Out:
# array([[ 160128.44461612],
#        [ 266022.80808982],
#        [ 263173.39535733],
#        ...,
#        [-291648.88036755],
#        [-292160.79548873],
#        [ 107677.20523019]])

# %%
import numpy as np

# %%
mylist = []
for element in mydata:
    mylist.append([element[0],])
np.array(mylist)
# Out:
# array([[ 160128.44461612],
#        [ 266022.80808982],
#        [ 263173.39535733],
#        ...,
#        [-291648.88036755],
#        [-292160.79548873],
#        [ 107677.20523019]])

# %%
mylist
# Out:
# [[160128.4446161192],
#  [266022.80808981851],
#  [263173.39535733132],
#  [259937.65065675965],
#  [256347.04547981251],
#  [252451.21469275188],
#  [248220.15528110834],
#  [243733.34316754839],
#  [238964.81025248286],
#  [233958.71612230098],
#  [228719.77081562334],
#  [223269.86004598913],
#  [217623.19378401336],
#  [211796.39825006001],
#  [205804.96760928386],
#  [199664.59361059839],
#  [193390.80962504441],
#  [186999.15771672831],
#  [180505.1682198965],
#  [173924.38031706068],
#  [167272.33747412218],
#  [160564.57857186979],
#  [153816.61990987827],
#  [147043.9326260355],
#  [140261.91550635232],
#  [133485.8642361548],
#  [126730.93895493187],
#  [120012.12760862987],
#  [113344.21043834616],
#  [106741.7217854257],
#  [100218.91275926564],
#  [93789.713323958],
#  [87467.695152091401],
#  [81266.03482366215],
#  [75197.477558904546],
#  [69274.303471434105],
#  [63508.293563330466],
#  [57910.698457069913],
#  [52492.207728217167],
#  [47262.92182385554],
# ...

# %%
system.locals.temperatureField.data.shape
# Out:
# (5265, 1)

# %%
mygrad.evaluate().shape
# Out:
# (5265, 1)
