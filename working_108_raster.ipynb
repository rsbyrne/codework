# %%
import planetengine

# %%
system = planetengine.systems.Isovisc(
    res = 64,
    alpha = 1e7,
    aspect = 3.,
    temperatureField = planetengine.initials.Sinusoidal(freq = 2.)
    )

# %%
system.initialise()

# %%
system.add_observer()
# Out:
# ;

# %%
system.observer.raster.img
# Out:
# <PIL.Image.Image image mode=RGB size=768x256 at 0x7F9511E06B38>

# %%
system.show()
# Out:
# <img src='data:image/png;base64,...'>

# %%
system[:3000:100]()
# Out:
# >
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# ;
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# ;
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# ;
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# ;
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# ;
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# ;
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# ;
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# ;
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# ;
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# ;
# ;
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# ;
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# ;
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# ;
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# ;
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# ;
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# ;
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# ;
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# ;
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# ;
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# ;
# ;
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# ;
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# ;
# .
# .
# .
# .
# .
# ...

# %%
animated = planetengine.visualisation.raster.animate(
    system.observer.dataDict['raster'],
    system.observer.dataDict['chron'],
    pts = 2.
    )

# %%
from IPython.display import Video
Video(animated, embed = True)
# Out:
# <video controls  >
#  <source src="data:video/mp4;base64,..." type="video/mp4">
#  Your browser does not support the video tag.
#  </video>

# %%
planetengine.quickShow(system.locals.temperatureField, system.observer.streamFn, system.locals.velocityField)
# Out:
# <img src='data:image/png;base64,...'>

# %%
from planetengine.visualisation import raster

# %%
system.observer.raster.img
# Out:
# <PIL.Image.Image image mode=RGB size=768x256 at 0x7F94CA57DFD0>

# %%
raster.rasterise(raster.split_imgArr(system.observer.raster.data)[0])
# Out:
# <PIL.Image.Image image mode=L size=768x256 at 0x7F95120252E8>

# %%
raster.rasterise(raster.split_imgArr(system.observer.raster.data)[1])
# Out:
# <PIL.Image.Image image mode=L size=768x256 at 0x7F94EA2599B0>

# %%
raster.rasterise(raster.split_imgArr(system.observer.raster.data)[2])
# Out:
# <PIL.Image.Image image mode=L size=768x256 at 0x7F94DFFFDB70>

# %%
dir(system.observer.raster)
# Out:
# ['__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  '_save',
#  '_show',
#  '_update',
#  '_update_data',
#  '_update_img',
#  'add',
#  'data',
#  'dataObjs',
#  'enlarge',
#  'evaluate',
#  'ext',
#  'img',
#  'name',
#  'resize',
#  'save',
#  'shape',
#  'show',
#  'update']
