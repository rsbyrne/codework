# %%
import sys
sys.path.append('/home/jovyan/workspace')

# %%
# from planetengine.tests import framestest

# %%
from planetengine import tests

# %%
tests.framestest.testfn()
# Out:
# Making stamps...
# Stamps made.
# Making a new frame...
# Building frame...
# Making stamps...
# Stamps made.
# Fitted 0 variables to the figure.
# Initialising...
# Initialisation complete!
# Frame built!
# Loading checkpoint...
# Already at step 0: aborting load_checkpoint.
# Making stamps...
# Stamps made.
# Making a new frame...
# Building frame...
# Making stamps...
# Stamps made.
# Fitted 0 variables to the figure.
# Initialising...
# Mapping achieved at tolerance = 0.00028032395844273904
# Initialisation complete!
# Frame built!
# Collecting...
# Collecting complete!
# No pre-existing directory for this model found. Making a new one...
# Collecting...
# Collecting complete!
# No pre-existing directory for this model found. Making a new one...
# Checkpointing...
# Making checkpoint directory.
# Saving figures...
# Figures saved.
# Saving vars of state...
# Saving substrate to disk: mesh
# Saving var to disk: temperatureField
# Saved.
# Saving snapshot...
# Snapshot saved.
# Saving modeltime...
# Modeltime saved.
# Saving stamps...
# Stamps saved.
# Saving datasets...
# Datasets saved.
# Checkpointed!
# Checkpointing...
# Making checkpoint directory.
# Saving figures...
# Figures saved.
# Saving vars of state...
# Saving substrate to disk: mesh
# Saving var to disk: temperatureField
# Saved.
# Saving snapshot...
# Snapshot saved.
# Saving modeltime...
# Modeltime saved.
# Saving stamps...
# Stamps saved.
# Saving datasets...
# Datasets saved.
# Checkpointed!
# Clearing all data...
# All data cleared!
# Archiving...
# Making a local archive...
# ../data/test/pemod_foul-darwinite
# Deleting model directory...
# Model directory deleted.
# Archived!
# Making a backup...
# Forking model to new directory...
# Model forked to directory: ../data/test/backup
# Backup saved.
# Loading checkpoint...
# Already at step 0: aborting load_checkpoint.
# Making stamps...
# Stamps made.
# Preexisting frame found! Loading...
# Tar found - unarchiving...
# Unarchived.
# Building frame...
# Making stamps...
# Stamps made.
# Fitted 0 variables to the figure.
# Initialising...
# Initialisation complete!
# Frame built!
# Found checkpoint: 00000000
# Loading checkpoint...
# Already at step 0: aborting load_checkpoint.
# Building frame...
# Making stamps...
# Stamps made.
# Fitted 0 variables to the figure.
# Initialising...
# Mapping achieved at tolerance = 0.00028032395844273904
# Initialisation complete!
# Frame built!
# Found checkpoint: 00000000
# Loading checkpoint...
# Already at step 0: aborting load_checkpoint.
# Archiving...
# Making a local archive...
# ../data/test/pemod_foul-darwinite
# Deleting model directory...
# Model directory deleted.
# Archived!
# Iterating step 0 ...
# Iteration complete!
# Unarchiving...
# Unarchiving the local archive...
# Deleting archive...
# Model directory deleted.
# Unarchived!
# Archiving...
# Making a local archive...
# ../data/test/pemod_foul-darwinite
# Deleting model directory...
# Model directory deleted.
# Archived!
# Collecting...
# Collecting complete!
# Unarchiving...
# Unarchiving the local archive...
# Deleting archive...
# Model directory deleted.
# Unarchived!
# Pre-existing directory for this model has been found. Continuing...
# Checkpointing...
# Making checkpoint directory.
# Saving figures...
# Figures saved.
# Saving vars of state...
# Saving substrate to disk: mesh
# Saving var to disk: temperatureField
# Saved.
# Saving snapshot...
# Snapshot saved.
# Saving modeltime...
# Modeltime saved.
# Saving stamps...
# Stamps saved.
# Saving datasets...
# Datasets saved.
# Checkpointed!
# Clearing all data...
# All data cleared!
# Archiving...
# Making a local archive...
# ../data/test/pemod_foul-darwinite
# Deleting model directory...
# Model directory deleted.
# Archived!
# Making a backup...
# Forking model to new directory...
# Model forked to directory: ../data/test/backup
# Backup saved.
# Success!
