# %%
import sys
workPath = '/home/jovyan/workspace'
if not workPath in sys.path:
    sys.path.append(workPath)

# %%
import planetengine

# %%
system = planetengine.tests.testsystems.get_system()
# Out:
# Fitted 1 variables to the figure.

# %%
planetengine.quickShow(system.temperatureField)
# Out:
# Fitted 1 variables to the figure.
# Variable_varName=anon{}
# <img src='data:image/png;base64,...'>

# %%
observer = planetengine.observers.standard.build()

# %%
observer.attach(system)
# Out:
# Fitted 2 variables to the figure.

# %%
observer.report()
# Out:
# avStress
# 49903.69
# avTemp
# 0.45
# modeltime
# 0.0E+00
# Nu
# 1.00
# step
# 0
# surfVRMS
# -3.95
# VRMS
# 108.75
# Variable_varName=temperature{}
# Variable_varName=velocity{}
# <img src='data:image/png;base64,...'>

# %%
system.go(10)

# %%
observer.report()
# Out:
# avStress
# 49903.69
# avTemp
# 0.45
# modeltime
# 4.6E-05
# Nu
# 1.00
# step
# 10
# surfVRMS
# -4.62
# VRMS
# 121.18
# Variable_varName=temperature{}
# Variable_varName=velocity{}
# <img src='data:image/png;base64,...'>

# %%
observer.prompt()
# Out:
# Observer prompted.
# Observer collecting...
# Observer collected.

# %%
outPath = planetengine.paths.make_testdir()

# %%
observer.checkpoint(outPath)
# Out:
# Observer checkpointing...
# Attempting to checkpoint...
# Bananas! 10
# Apricots! /home/jovyan/workspace/out/test/peobs_jaguarao-lieger
# Checking for pre-existing frame on disk...
# No pre-existing directory for this model found. Making a new one...
# Checkpointing...
# Making checkpoint directory.
# Saving figures...
# Figures saved.
# Saving vars of state...
# Saving substrate to disk: mesh
# Saving var to disk: stress
# Saving var to disk: velocity
# Saved.
# Saving snapshot...
# Snapshot saved.
# Saving datasets...
# Datasets saved.
# Checkpointed!
# Observer checkpointed.

# %%
observer2 = planetengine._observer.load_observer(observer.instanceID, outPath)
# Out:
# Fitted 1 variables to the figure.
# Fitted 2 variables to the figure.

# %%
mymodel = planetengine.model.make_model(system)
# Out:
# Making a new frame...
# Building model...
# Initialising...
# Initialisation complete!
# Frame built!
