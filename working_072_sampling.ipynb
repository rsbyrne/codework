# %%
import sys
workPath = '/home/jovyan/workspace'
if not workPath in sys.path:
    sys.path.append(workPath)

# %%
import planetengine
copyField = planetengine.fieldops.copyField

# %%
system = planetengine.systems.isovisc.build(f = 1., res = 16)
temperature = system.obsVars['temperature']
system.go(100)

# %%
newsystem = planetengine.systems.isovisc.build(f = 0.5, aspect = 2., res = 32)
newtemperature = newsystem.obsVars['temperature']

# %%
tolerance = copyField(temperature ** 2, newtemperature)
print(tolerance)
# Out:
# 1e-05

# %%
planetengine.quickShow(temperature ** 2)
# Out:
# Vanilla{-9223363300337576020}
# <img src='data:image/png;base64,...'>

# %%
planetengine.quickShow(newtemperature)
# Out:
# Variable{8736496253693}
# <img src='data:image/png;base64,...'>
