# %%
import sys
workPath = '/home/jovyan/workspace'
if not workPath in sys.path:
    sys.path.append(workPath)

# %%
import underworld as uw

# %%
import planetengine
quickShow = planetengine.quickShow

# %%
system = planetengine.tests.testsystems.arrhenius()

# %%
meshUtils = planetengine.meshutils.get_meshUtils(system.mesh)

# %%
myvar = meshUtils.meshify(system.viscosityFn)

# %%
myvar = meshUtils.meshify(system.viscosityFn)

# %%
meshUtils.meshifieds
# Out:
# {9841538263278943694: <weakref at 0x7f5de8513ef8; to 'MeshVariable' at 0x7f5de85c2c18>}

# %%
myvar2 = meshUtils.meshify(system.viscosityFn, rounding = 0)

# %%
meshUtils.meshifieds
# Out:
# {1296426806261129068: <weakref at 0x7f5de8537318; to 'MeshVariable' at 0x7f5de851a198>,
#  9841538263278943694: <weakref at 0x7f5de8513ef8; to 'MeshVariable' at 0x7f5de85c2c18>}

# %%
import glucifer

# %%
myfig = glucifer.Figure()

# %%
myfig.append(glucifer.objects.Surface(myvar.mesh, myvar))

# %%
myfig.show()
# Out:
# <img src='data:image/png;base64,...'>

# %%
myfig = glucifer.Figure()

# %%
myfig.append(glucifer.objects.Surface(myvar2.mesh, myvar2))

# %%
myfig.show()
# Out:
# <img src='data:image/png;base64,...'>

# %%
myvar.data[20]
# Out:
# array([ 139.193337])

# %%
myvar2.data[20]
# Out:
# array([ 139.])

# %%
system.iterate()

# %%
myvar.lasthash
# Out:
# 5738817491643093054

# %%
myvar.project()

# %%
myvar.lasthash
# Out:
# 3217553835938469626
