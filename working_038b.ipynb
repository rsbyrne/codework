# %%
import sys
sys.path.append('/home/jovyan/workspace')

# %%
import numpy as np
from underworld import function as fn

from modelscripts import arrhenius
from planetengine import quickShow
import planetengine
from planetengine import functions

# %%
system = arrhenius.build(res = 16, Ra = 1e4, f = 0.5, aspect = 1., eta0 = 10.)
planetengine.initials.apply(
    {'temperatureField': planetengine.initials.sinusoidal.IC(freq = 1.)},
    system,
    )
system.solve()

# %%
planetengine.quickShow(system.temperatureField)
# Out:
# Fitted 1 variables to the figure.
# Variable_varName=anon{} [ 1.]
# <img src='data:image/png;base64,...'>

# %%
planetengine.quickShow(system.viscosityFn)
# Out:
# Fitted 1 variables to the figure.
# Variable_varName=anon{} [ 9.]
# <img src='data:image/png;base64,...'>

# %%
fn3 = functions.tidy.simple.normalise(system.temperatureField, system.viscosityFn)

# %%
fn3.varName
# Out:
# 'Normalise{Variable_varName=anon{};Variable_varName=anon{}}'

# %%
planetengine.quickShow(fn3)
# Out:
# Fitted 1 variables to the figure.
# Normalise{Variable_varName=anon{};Variable_varName=anon{}} [ 9.]
# <img src='data:image/png;base64,...'>

# %%
fn4 = functions.tidy.simple.getstat.ranges(fn3)

# %%
fn4.evaluate()
# Out:
# array([[ 9.]])
