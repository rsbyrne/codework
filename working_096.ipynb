# %%
import sys
import os
workPath = os.path.abspath('..')
if not workPath in sys.path:
    sys.path.append(workPath)

# %%
name = 'test'
outputPath = '..'
from everest import mpi
import os
# fullpath = os.path.join(os.path.abspath(outputPath), name) + '.frm'
# if mpi.rank == 0:
#     if os.path.exists(fullpath):
#         os.remove(fullpath)
from everest.builts import set_global_anchor
set_global_anchor(name, outputPath)
from everest.builts import GLOBALREADER as reader

# %%
reader['*']
# Out:
# {'aitiafief-eafieomai/inputs/cosmos': ibgepxrfoiknedlc.py.Isovisc,
#  'daescbluid-yeaspkruach/traversee': 'bliurhsloez-sliaxphul',
#  'hazhuuskou-kwuaplauzhau/inputsHash': 202484249888170947911243618399328801547,
#  'ngaiblfrec-psuipoekwei/inputs/express': True,
#  'choqooxie-ioskuilaips/inputs/state': <everest.builts.states._threshold.Threshold at 0x7f8bcbfede10>,
#  'chauwskouc-ousfavaang/inputs/cosmos': ihojxzrvivyskxqc.py.Isovisc,
#  'wuusktiedr-tsuadsciekw/inputs/urey': 0.0,
#  'oagaiengui-atsuascieg/class': planetengine._traverse.Traverse,
#  'wuusktiedr-tsuadsciekw/outputs/temperatureDotField': array([[[ 0.        ],
#          [ 0.        ],
#          [ 0.        ],
#          ...,
#          [ 0.        ],
#          [ 0.        ],
#          [ 0.        ]],
#
#         [[ 0.        ],
#          [-0.0005938 ],
#          [-0.0011279 ],
#          ...,
#          [-0.00023904],
#          [-0.00011315],
#          [ 0.        ]]]),
#  'oufriabuigr-spiatwwioch/inputs/temperatureDotField': <udvyhckvaxrhjxxa.py.Constant at 0x7f8bcbe81dd8>,
#  'oegaiskoch-uocaaeifra/inputs/Ra': 10000.0,
#  'pruzeobruu-oaflaohaek/stamps': [('pruzeobruu-oaflaohaek', 0),
#   ('xeoxstiutr-eibroatsuubl', 1000)],
#  'ioklougiest-duangaakwii/instanceHash': 63783661653036903481720967613818169364,
#  'easmoaiikai-leaslpsiutw/inputs/temperatureField': <uqlrdbgirthtiooe.py.Sinusoidal at 0x7f8bcbf53d68>,
#  'plafruonee-qefleifoa/inputs/aspect': 1.0,
#  'swahkwaefl-fuuzhoaghi/inputs/express': True,
#  'ngoishwruedr-snaotaamia/outputs/temperatureField': array([[[ 1.        ],
#          [ 0.94914657],
#          [ 0.89848194],
#          ...,
#          [ 0.10151806],
#          [ 0.05085343],
#          [ 0.        ]],
#
#         [[ 1.        ],
#          [ 0.22573677],
#          [ 0.26083465],
#          ...,
#          [ 0.56204988],
#          [ 0.59830318],
#          [ 0.        ]]]),
#  'oephaokwaosp-uogloespezh/outputs/count': array([1000], dtype=int32),
#  'grazhrheong-aaviobriekl/inputs/temperatureDotField': <pkyzcdzvqnpuhlzz.py.Constant at 0x7f8bcbf396d8>,
#  'eigraaflausw-aatweuoastoo/outputs/count': array([   0, 1000], dtype=int32),
#  'preiphiukei-rhablgroigr/inputs/f': 0.9,
#  'wuusktiedr-tsuadsciekw/outputs/count': array([   0, 1000], dtype=int32),
#  'uafliueitrou-wreasngregl/inputsHash': 99085955928906296332257490963966454026,
#  'plafruonee-qefleifoa/hashID': 'plafruonee-qefleifoa',
#  'etwuinuufr-easnianeogr/inputs/aspect': 1.0,
#  'dwuiscuikwua-spiopfrikw/inputs/res': 32,
#  'jakwouplu-puetcoav/inputsHash': 301483453345408010666156771599206912643,
#  'pruubpruip-twuefpriasc/outputs/temperatureField': array([[[ 1.        ],
#          [ 0.94914657],
#          [ 0.89848194],
#          ...,
#          [ 0.10151806],
#          [ 0.05085343],
#          [ 0.        ]],
#
#         [[ 1.        ],
#          [ 0.80949752],
#          [ 0.63783089],
#          ...,
#          [ 0.25658771],
#          [ 0.13167482],
#          [ 0.        ]]]),
#  'oukwaithiugh-giosmiasho/inputs/temperatureDotField': <ifhlatjujkxkqtcw.py.Constant at 0x7f8bcbe8add8>,
#  'troarhflux-kwetsskuakw/inputs/temperatureField': <etcvycistpnijetv.py.Sinusoidal at 0x7f8bcbdf3f60>,
#  'choqooxie-ioskuilaips/_iterator_initialise': False,
#  'doaflophuo-oumjaeg/inputs/state': <everest.builts.states._threshold.Threshold at 0x7f8bcc008358>,
#  'looprbaeng-goozhfroim/hashID': 'looprbaeng-goozhfroim',
#  'ngoishwruedr-snaotaamia/inputs/temperatureField': <epzkcavizntsegbw.py.Sinusoidal at 0x7f8bcbe60b00>,
#  'oukwaithiugh-giosmiasho/instanceHash': 112390357544927589396997833576876289016,
#  'eigraaflausw-aatweuoastoo/inputs/f': 0.5,
#  'sibaiyea-iebrubliic/typeHash': 274522875136874358598349492847282620529,
#  'daattzoin-vispupei/typeHash': 277512443600939600534146158745604118014,
#  'keatoaque-aatzoueisnou/typeHash': 277512443600939600534146158745604118014,
#  'choqooxie-ioskuilaips/outputs/count': array([1000], dtype=int32),
#  'uasfiougroa-aokliitreabl/outputs/temperatureDotField': array([[[   0.        ],
#          [   0.        ],
#          [   0.        ],
#          ...,
#          [   0.        ],
#          [   0.        ],
#          [   0.        ]],
#
#         [[   0.        ],
#          [ -40.53537816],
#          [-219.5822433 ],
#          ...,
#          [-100.23180754],
#          [ -77.98851604],
#          [   0.        ]]]),
#  'eigleuopii-ariiglaest/inputs/f': 0.6,
#  'shaciipsie-iadriieejui/inputs/res': 32,
#  'idroiphaifl-pleakroejee/typeHash': 100175068238429420833077061383123783763,
#  'heikspiic-oevouiima/inputs/state': <everest.builts.states._threshold.Threshold at 0x7f8bcbed1cf8>,
#  'etwuinuufr-easnianeogr/instanceHash': 87266608294229687371949483922347942021,
#  'oufriabuigr-spiatwwioch/inputs/urey': 0.0,
#  'oephaokwaosp-uogloespezh/inputs/cosmos': cqcunyhkvqriaubs.py.Isovisc,
#  'qeibswuuwr-thoulspipr/stamps': [('qeibswuuwr-thoulspipr', 0),
#   ('xeoxstiutr-eibroatsuubl', 1000)],
#  'kiaghgruosk-aidrueiutwoe/inputs/express': True,
#  'troarhflux-kwetsskuakw/class': knikzirrhwsyffry.py.Isovisc,
#  'ihuotwuath-eeyaidwuik/inputs/Ra': 316227.7660168379,
#  'thiigriiwiu-psoesnutzeo/inputsHash': 73523140007659630323597631336034426815,
#  'wreanoigrou-briesnutuu/typeHash': 100175068238429420833077061383123783763,
#  'beakgoabr-eezuiougrio/typeHash': 100175068238429420833077061383123783763,
#  'ghoatrsfuagh-ceebaayua/typeHash': 100175068238429420833077061383123783763,
#  'jaokngoatr-eafoapraitz/inputs/temperatureDotField': <uyhloziitpemnaki.py.Constant at 0x7f8bcbf0a9b0>,
#  'shaadwiupo-jeaphsteapr/outputs/count': array([   0, 1000], dtype=int32),
#  'oukwaithiugh-giosmiasho/inputs/res': 32,
#  'daescbluid-yeaspkruach/inputs/express': True,
#  'beakgoabr-eezuiougrio/inputs/aspect': 1.0,
#  'aitiafief-eafieomai/typeHash': 277512443600939600534146158745604118014,
#  'oegaiskoch-uocaaeifra/stamps': [('oegaiskoch-uocaaeifra', 0),
#   ('xeoxstiutr-eibroatsuubl', 1000)],
#  'xeoxstiutr-eibroatsuubl/typeHash': 159307469463883229441668875084382572402,
#  'iiloeugroi-ouswaisoasw/inputs/state': <everest.builts.states._threshold.Threshold at 0x7f8bcbee3ba8>,
#  'fluokblaep-wruowstiakw/outputs/count': array([1000], dtype=int32),
#  'guoxgruf-naorhsluid/hashID': 'guoxgruf-naorhsluid',
#  'heikspiic-oevouiima/typeHash': 277512443600939600534146158745604118014,
#  'jaokngoatr-eafoapraitz/hashID': 'jaokngoatr-eafoapraitz',
#  'preiphiukei-rhablgroigr/outputs/temperatureDotField': array([[[  0.00000000e+00],
#          [  0.00000000e+00],
#          [  0.00000000e+00],
#          ...,
#          [  0.00000000e+00],
#          [  0.00000000e+00],
#          [  0.00000000e+00]],
#
#         [[  0.00000000e+00],
#          [ -3.12081745e-05],
#          [ -6.49112785e-05],
#          ...,
#          [ -2.46395591e-04],
#          [ -1.28864874e-04],
#          [  0.00000000e+00]]]),
#  'heikspiic-oevouiima/inputs/cosmos': gwwdugtjxehwxlgr.py.Isovisc,
#  'swahkwaefl-fuuzhoaghi/vector': 25088213989150610309583788406579308349,
#  'plafruonee-qefleifoa/inputsHash': 131759314329846700081637916045029592021,
#  'swahkwaefl-fuuzhoaghi/inputs/cosmos': mulijhukbnbjensk.py.Isovisc,
#  'uafliueitrou-wreasngregl/inputs/temperatureField': <qxstjxoeoqayomfb.py.Sinusoidal at 0x7f8bcbe02f98>,
#  'ngoishwruedr-snaotaamia/outputs/count': array([   0, 1000], dtype=int32),
#  'wreanoigrou-briesnutuu/outputs/count': array([   0, 1000], dtype=int32),
#  'oegaiskoch-uocaaeifra/inputs/temperatureField': <pwdqpmhbvopbcrwb.py.Sinusoidal at 0x7f8bcbe73ef0>,
#  'kwooheagr-wriishuarhei/inputs/f': 0.7,
#  'heikspiic-oevouiima/inputs/f': 0.7,
#  'pheeklphiatz-rouspeits/inputs/cosmos': turxzfohkatxqzzx.py.Isovisc,
#  'wreanoigrou-briesnutuu/outputs/temperatureField': array([[[ 1.        ],
#          [ 0.94914657],
#          [ 0.89848194],
#          ...,
#          [ 0.10151806],
#          [ 0.05085343],
#          [ 0.        ]],
#
#         [[ 1.        ],
#          [ 0.81714785],
#          [ 0.65080222],
#          ...,
#          [ 0.2731374 ],
#          [ 0.14060106],
#          [ 0.        ]]]),
#  'guoxgruf-naorhsluid/inputs/cosmos': ozwkzisunzjzqbhv.py.Isovisc,
#  'bukweaglao-oefriouofii/_iterator_initialise': False,
#  'ihuotwuath-eeyaidwuik/outputs/temperatureField': array([[[ 1.        ],
#          [ 0.94914657],
#          [ 0.89848194],
#          ...,
#          [ 0.10151806],
#          [ 0.05085343],
#          [ 0.        ]],
#
#         [[ 1.        ],
#          [ 0.14374808],
#          [ 0.14635641],
#          ...,
#          [ 0.66275244],
#          [ 0.61273055],
#          [ 0.        ]]]),
#  'daescbluid-yeaspkruach/inputs/Ra': 31622.776601683792,
#  'uasfiougroa-aokliitreabl/inputs/f': 0.9,
#  'sibaiyea-iebrubliic/instanceHash': 326789652242860034119404837256448312910,
#  'shaciipsie-iadriieejui/hashID': 'shaciipsie-iadriieejui',
#  'euteiaiyae-blaugrslouw/typeHash': 277512443600939600534146158745604118014,
#  'bliurhsloez-sliaxphul/typeHash': 100175068238429420833077061383123783763,
#  'xuiklnousl-tiosrhaap/inputsHash': 113032409169739638612062685138239979105,
#  'fiubrpsuek-soanfiey/outputs/count': array([1000], dtype=int32),
#  'jakwouplu-puetcoav/inputs/Ra': 10000.0,
#  'bliurhsloez-sliaxphul/instanceHash': 287571109504882032133420796305501668715,
#  'plafruonee-qefleifoa/inputs/f': 0.7,
#  'easmoaiikai-leaslpsiutw/outputs/temperatureDotField': array([[[ 0.        ],
#          [ 0.        ],
#          [ 0.        ],
#          ...,
#          [ 0.        ],
#          [ 0.        ],
#          [ 0.        ]],
#
#         [[ 0.        ],
#          [ 0.00870712],
#          [ 0.01765672],
#          ...,
#          [-0.03396235],
#          [-0.01783464],
#          [ 0.        ]]]),
#  'ioklougiest-duangaakwii/typeHash': 277512443600939600534146158745604118014,
#  'hazhuuskou-kwuaplauzhau/hashID': 'hazhuuskou-kwuaplauzhau',
#  'uasfiougroa-aokliitreabl/hashID': 'uasfiougroa-aokliitreabl',
#  'troarhflux-kwetsskuakw/inputs/res': 32,
#  'ihuotwuath-eeyaidwuik/class': dfccfdqbwhlffbvu.py.Isovisc,
#  'kuekjoigh-toaxrhauth/inputs/temperatureDotField': <limjinsmujvweuuk.py.Constant at 0x7f8bcbea5d30>,
#  'auqiuuozau-sweadrpriasw/outputs/temperatureDotField': array([[[ 0.        ],
#          [ 0.        ],
#          [ 0.        ],
#          ...,
#          [ 0.        ],
#          [ 0.        ],
#          [ 0.        ]],
#
#         [[ 0.        ],
#          [-0.20544941],
#          [-0.30336951],
#          ...,
#          [ 0.30915208],
#          [ 0.21786615],
#          [ 0.        ]]]),
#  'ueguifuifr-plaejtraic/instanceHash': 233401909465891514583836625865276206697,
#  'chieslkeut-iogoaasma/inputs/temperatureField': <kahvgefcfcdpiylb.py.Sinusoidal at 0x7f8bcbfed630>,
#  'oukwaithiugh-giosmiasho/outputs/count': array([   0, 1000], dtype=int32),
#  'euteiaiyae-blaugrslouw/hashID': 'euteiaiyae-blaugrslouw',
#  'dwuiscuikwua-spiopfrikw/outputs/count': array([1000], dtype=int32),
#  'doaflophuo-oumjaeg/instanceHash': 53157915614816412277517569908149707181,
#  'moebleaswua-uakrxeiz/inputs/state': <everest.builts.states._threshold.Threshold at 0x7f8bcbecad68>,
#  'thiigriiwiu-psoesnutzeo/inputs/Ra': 3162.2776601683795,
#  'uasfiougroa-aokliitreabl/stamps': [('uasfiougroa-aokliitreabl', 0),
#   ('xeoxstiutr-eibroatsuubl', 1000)],
#  'ioklougiest-duangaakwii/inputsHash': 45313467356569373891956652527806628790,
#  'iuswuithiif-roosckweabl/inputsHash': 156597475970858069498444288439911944178,
#  'uuwiiskeedw-oafleuuezhue/inputsHash': 14072272172705512124600904435981565415,
#  'beakgoabr-eezuiougrio/inputs/f': 0.8,
#  'pheeklphiatz-rouspeits/traversee': 'laetzgroofl-ngiriobii',
#  'thaaflviusp-ixaufliust/inputs/cosmos': boarocgckowsbosf.py.Isovisc,
#  'daattzoin-vispupei/inputs/state': <everest.builts.states._threshold.Threshold at 0x7f8bcbff84e0>,
#  'kriobrusmuu-fruetzswuips/class': cyflluxdggnrmasw.py.Sinusoidal,
#  'fluokblaep-wruowstiakw/vector': 14072272172705512124600904435981565415,
#  'uziiiesfuo-aomaitraeb/instanceHash': 337188431769512296119408706056947919430,
#  'hazhuuskou-kwuaplauzhau/instanceHash': 21409061296300590315369395563176112247,
#  'fluokblaep-wruowstiakw/class': planetengine._traverse.Traverse,
#  'shaciipsie-iadriieejui/inputs/state': <everest.builts.states._threshold.Threshold at 0x7f8bcbde0be0>,
#  'qeibswuuwr-thoulspipr/outputs/chron': array([ 0.        ,  0.03603863]),
#  'ngaiblfrec-psuipoekwei/hashID': 'ngaiblfrec-psuipoekwei',
#  'oufriabuigr-spiatwwioch/inputs/f': 0.7,
#  'qeibswuuwr-thoulspipr/inputs/res': 32,
#  'gloifaoree-juayzeidr/inputs/Ra': 10000.0,
#  'auqoeigrei-huupsswoich/inputs/cosmos': cnqmqptpwtcktzpz.py.Isovisc,
#  'eigleuopii-ariiglaest/outputs/temperatureField': array([[[ 1.        ],
#          [ 0.94914657],
#          [ 0.89848194],
#          ...,
#          [ 0.10151806],
#          [ 0.05085343],
#          [ 0.        ]],
#
#         [[ 1.        ],
#          [ 0.21678277],
#          [ 0.26780199],
#          ...,
#          [ 0.65029285],
#          [ 0.71859783],
#          [ 0.        ]]]),
#  'ihuotwuath-eeyaidwuik/hashID': 'ihuotwuath-eeyaidwuik',
#  'laetzgroofl-ngiriobii/outputs/count': array([   0, 1000], dtype=int32),
#  'aitiafief-eafieomai/traversee': 'uafliueitrou-wreasngregl',
#  'kiaghgruosk-aidrueiutwoe/inputs/cosmos': wcvfyeqoztodmlnx.py.Isovisc,
#  'pruubpruip-twuefpriasc/instanceHash': 252208003625747261123505538371641924493,
#  'auqiuuozau-sweadrpriasw/hashID': 'auqiuuozau-sweadrpriasw',
#  'qeibswuuwr-thoulspipr/typeHash': 100175068238429420833077061383123783763,
#  'daattzoin-vispupei/traversee': 'oegaiskoch-uocaaeifra',
#  'pruzeobruu-oaflaohaek/outputs/count': array([   0, 1000], dtype=int32),
#  'bukweaglao-oefriouofii/hashID': 'bukweaglao-oefriouofii',
#  'easmoaiikai-leaslpsiutw/inputs/f': 0.7,
#  'guoxgruf-naorhsluid/inputs/Ra': 10000.0,
#  'iiloeugroi-ouswaisoasw/inputs/express': True,
#  'choqooxie-ioskuilaips/inputs/f': 0.9,
#  'ghoatrsfuagh-ceebaayua/inputs/aspect': 1.0,
#  'swahkwaefl-fuuzhoaghi/typeHash': 277512443600939600534146158745604118014,
#  'oephaokwaosp-uogloespezh/inputs/state': <everest.builts.states._threshold.Threshold at 0x7f8bcbe81278>,
#  'ihuotwuath-eeyaidwuik/inputs/urey': 0.0,
#  'pruubpruip-twuefpriasc/outputs/count': array([   0, 1000], dtype=int32),
#  'choqooxie-ioskuilaips/inputsHash': 258418270930454286853355951818790486926,
#  'shaciipsie-iadriieejui/inputs/express': True,
#  'shaciipsie-iadriieejui/class': planetengine._traverse.Traverse,
#  'qeibswuuwr-thoulspipr/inputs/urey': 0.0,
#  'qeibswuuwr-thoulspipr/class': bqvdgubbqrxlzcok.py.Isovisc,
#  'eikroaprubr-uiteoetreu/inputs/express': True,
#  'keatoaque-aatzoueisnou/inputs/state': <everest.builts.states._threshold.Threshold at 0x7f8bcbe99400>,
#  'iopliiaupseu-jioblscuir/inputs/temperatureDotField': <vnoesaxgqduczjwy.py.Constant at 0x7f8bcbef1c88>,
#  'pruzeobruu-oaflaohaek/inputs/urey': 0.0,
#  'dwuiscuikwua-spiopfrikw/instanceHash': 89962800071446939416563107673209875193,
#  'oagaiengui-atsuascieg/inputs/res': 32,
#  'ngoishwruedr-snaotaamia/inputsHash': 147622199526428355556101817935610041757,
#  'ihuotwuath-eeyaidwuik/outputs/temperatureDotField': array([[[   0.        ],
#          [   0.        ],
#          [   0.        ],
#          ...,
#          [   0.        ],
#          [   0.        ],
#          [   0.        ]],
#
#         [[   0.        ],
#          [  69.6340653 ],
#          [  36.65505384],
#          ...,
#          [ 122.83989917],
#          [ 112.14085969],
#          [   0.        ]]]),
#  'easmoaiikai-leaslpsiutw/inputs/Ra': 10000.0,
#  'troarhflux-kwetsskuakw/instanceHash': 244625470237774601039687737502113065051,
#  'oagaiengui-atsuascieg/typeHash': 277512443600939600534146158745604118014,
#  'euteiaiyae-blaugrslouw/vector': 189711283977171798690859183230409368188,
#  'troarhflux-kwetsskuakw/inputs/urey': 0.0,
#  'ngoishwruedr-snaotaamia/inputs/f': 0.5,
#  'uuwiiskeedw-oafleuuezhue/stamps': [('uuwiiskeedw-oafleuuezhue', 0),
#   ('xeoxstiutr-eibroatsuubl', 1000)],
#  'eigleuopii-ariiglaest/class': oibkfboesretctml.py.Isovisc,
#  'oukwaithiugh-giosmiasho/inputs/temperatureField': <sdzvjyrdgxsaiwmq.py.Sinusoidal at 0x7f8bcbe8af28>,
#  'azhefleudr-snipotzaa/inputs/cosmos': whxnqmowmrzgmlmp.py.Isovisc,
#  'jakwouplu-puetcoav/instanceHash': 267704345396905490798052835474301399279,
#  'ngoishwruedr-snaotaamia/outputs/chron': array([ 0.        ,  0.00875069]),
#  'uweoausk-waimieshoi/outputs/chron': array([ 0.        ,  0.21195529]),
#  'oegaiskoch-uocaaeifra/inputs/f': 0.5,
#  'troarhflux-kwetsskuakw/inputs/Ra': 31622.776601683792,
#  'shaadwiupo-jeaphsteapr/inputs/temperatureDotField': <bhxgdgjtorltwsqt.py.Constant at 0x7f8bcbdd2d30>,
#  'wuusktiedr-tsuadsciekw/inputsHash': 270460523462905496231914555615281261125,
#  'grazhrheong-aaviobriekl/class': gljyfgddjksfzyjx.py.Isovisc,
#  'moebleaswua-uakrxeiz/hashID': 'moebleaswua-uakrxeiz',
#  'iopliiaupseu-jioblscuir/inputs/temperatureField': <afqgpuakctbzmqnu.py.Sinusoidal at 0x7f8bcbef17f0>,
#  'eigraaflausw-aatweuoastoo/inputs/aspect': 1.0,
#  'kwoimdian-oujiusweesp/inputs/cosmos': ujidtagpntbrxpko.py.Isovisc,
#  'bukweaglao-oefriouofii/class': planetengine._traverse.Traverse,
#  'wreanoigrou-briesnutuu/inputs/urey': 0.0,
#  'ghoatrsfuagh-ceebaayua/inputs/Ra': 31622.776601683792,
#  'eigraaflausw-aatweuoastoo/hashID': 'eigraaflausw-aatweuoastoo',
#  'shaadwiupo-jeaphsteapr/inputs/urey': 0.0,
#  'daescbluid-yeaspkruach/inputs/f': 0.7,
#  'auqiuuozau-sweadrpriasw/inputs/aspect': 1.0,
#  'chauwskouc-ousfavaang/vector': 10838006864816936863569343237428045938,
#  'looprbaeng-goozhfroim/inputs/Ra': 316227.7660168379,
#  'euteiaiyae-blaugrslouw/inputs/express': True,
#  'jakwouplu-puetcoav/_iterator_initialise': False,
#  'eikroaprubr-uiteoetreu/inputs/res': 32,
#  'jakwouplu-puetcoav/outputs/count': array([1000], dtype=int32),
#  'ioklougiest-duangaakwii/inputs/f': 1.0,
#  'preiphiukei-rhablgroigr/outputs/chron': array([ 0.        ,  0.43726441]),
#  'aitiafief-eafieomai/instanceHash': 38253352975611371032978252951781203417,
#  'beakgoabr-eezuiougrio/inputsHash': 242658252457683324867035308727889980653,
#  'ghoatrsfuagh-ceebaayua/inputs/res': 32,
#  'eigleuopii-ariiglaest/inputs/Ra': 1000000.0,
#  'gloifaoree-juayzeidr/outputs/chron': array([ 0.        ,  0.19891856]),
#  'bukweaglao-oefriouofii/typeHash': 277512443600939600534146158745604118014,
#  'fiubrpsuek-soanfiey/instanceHash': 283124311389747361178474239559493300494,
#  'xeoxstiutr-eibroatsuubl/inputs/prop': 'count',
#  'easmoaiikai-leaslpsiutw/outputs/temperatureField': array([[[ 1.        ],
#          [ 0.94914657],
#          [ 0.89848194],
#          ...,
#          [ 0.10151806],
#          [ 0.05085343],
#          [ 0.        ]],
#
#         [[ 1.        ],
#          [ 0.72626614],
#          [ 0.50478269],
#          ...,
#          [ 0.39501437],
#          [ 0.21342123],
#          [ 0.        ]]]),
#  'swahkwaefl-fuuzhoaghi/hashID': 'swahkwaefl-fuuzhoaghi',
#  'fluokblaep-wruowstiakw/inputs/state': <everest.builts.states._threshold.Threshold at 0x7f8bcbf8d588>,
#  'bukweaglao-oefriouofii/inputs/Ra': 100000.0,
#  'easmoaiikai-leaslpsiutw/inputsHash': 25088213989150610309583788406579308349,
#  'easmoaiikai-leaslpsiutw/inputs/res': 32,
#  'wuusktiedr-tsuadsciekw/hashID': 'wuusktiedr-tsuadsciekw',
#  'jaokngoatr-eafoapraitz/stamps': [('jaokngoatr-eafoapraitz', 0),
#   ('xeoxstiutr-eibroatsuubl', 1000)],
#  'ngoishwruedr-snaotaamia/outputs/temperatureDotField': array([[[   0.        ],
#          [   0.        ],
#          [   0.        ],
#          ...,
#          [   0.        ],
#          [   0.        ],
#          [   0.        ]],
#
#         [[   0.        ],
#          [-218.67701594],
#          [ 153.71748889],
#          ...,
#          [  10.60326434],
#          [ 148.32956574],
#          [   0.        ]]]),
#  'laetzgroofl-ngiriobii/typeHash': 100175068238429420833077061383123783763,
#  'hazhuuskou-kwuaplauzhau/class': everest.builts._container.Container,
#  'kuekjoigh-toaxrhauth/inputs/temperatureField': <ognwxkjndnayrzda.py.Sinusoidal at 0x7f8bcbea5c50>,
#  'heikspiic-oevouiima/inputs/express': True,
#  'gloifaoree-juayzeidr/inputs/temperatureDotField': <xzfihdeesekosefs.py.Constant at 0x7f8bcbeef668>,
#  'kiaghgruosk-aidrueiutwoe/class': planetengine._traverse.Traverse,
#  'qeibswuuwr-thoulspipr/inputs/temperatureDotField': <ozuufncmvplvpmmt.py.Constant at 0x7f8bcbe48b70>,
#  'idroiphaifl-pleakroejee/inputs/aspect': 1.0,
#  'pruzeobruu-oaflaohaek/hashID': 'pruzeobruu-oaflaohaek',
#  'doaflophuo-oumjaeg/class': planetengine._traverse.Traverse,
#  'ueguifuifr-plaejtraic/inputs/express': True,
#  'looprbaeng-goozhfroim/stamps': [('looprbaeng-goozhfroim', 0),
#   ('xeoxstiutr-eibroatsuubl', 1000)],
#  'ihuotwuath-eeyaidwuik/typeHash': 100175068238429420833077061383123783763,
#  'fiubrpsuek-soanfiey/inputs/f': 1.0,
#  'keatoaque-aatzoueisnou/inputs/cosmos': eduxjglyvkvcemuu.py.Isovisc,
#  'etwuinuufr-easnianeogr/outputs/temperatureDotField': array([[[ 0.        ],
#          [ 0.        ],
#          [ 0.        ],
#          ...,
#          [ 0.        ],
#          [ 0.        ],
#          [ 0.        ]],
#
#         [[ 0.        ],
#          [ 0.34914877],
#          [-1.06802299],
#          ...,
#          [ 0.33261868],
#          [-0.16893136],
#          [ 0.        ]]]),
#  'beakgoabr-eezuiougrio/outputs/count': array([   0, 1000], dtype=int32),
#  'moebleaswua-uakrxeiz/typeHash': 277512443600939600534146158745604118014,
#  'oegaiskoch-uocaaeifra/hashID': 'oegaiskoch-uocaaeifra',
#  'eigleuopii-ariiglaest/typeHash': 100175068238429420833077061383123783763,
#  'shaciipsie-iadriieejui/instanceHash': 251635299074692512624815739056892606399,
#  'oukwaithiugh-giosmiasho/inputs/aspect': 1.0,
#  'daattzoin-vispupei/instanceHash': 246046837943732821025424864095137552343,
#  'oukwaithiugh-giosmiasho/hashID': 'oukwaithiugh-giosmiasho',
#  'choqooxie-ioskuilaips/inputs/res': 32,
#  'kwooheagr-wriishuarhei/inputsHash': 100930134878912879086654368989221539415,
#  'ueguifuifr-plaejtraic/inputs/cosmos': hrusmluyjbntqpcm.py.Isovisc,
#  'oephaokwaosp-uogloespezh/inputs/res': 32,
#  'fiubrpsuek-soanfiey/vector': 83708990928714596842284520908736605773,
#  'uafliueitrou-wreasngregl/hashID': 'uafliueitrou-wreasngregl',
#  'dwuiscuikwua-spiopfrikw/inputs/Ra': 316227.7660168379,
#  'shaciipsie-iadriieejui/inputs/Ra': 10000.0,
#  'pruzeobruu-oaflaohaek/inputsHash': 83708990928714596842284520908736605773,
#  'uasfiougroa-aokliitreabl/inputsHash': 114376224404368099975245152677862467187,
#  'thiigriiwiu-psoesnutzeo/hashID': 'thiigriiwiu-psoesnutzeo',
#  'ihuotwuath-eeyaidwuik/outputs/chron': array([ 0.        ,  0.01683947]),
#  'fluokblaep-wruowstiakw/traversee': 'uuwiiskeedw-oafleuuezhue',
#  'etwuinuufr-easnianeogr/inputs/f': 0.5,
#  'azhefleudr-snipotzaa/inputsHash': 321446314190348720349242704114784079579,
#  'easmoaiikai-leaslpsiutw/inputs/urey': 0.0,
#  'keatoaque-aatzoueisnou/inputs/f': 1.0,
#  'jaokngoatr-eafoapraitz/outputs/chron': array([ 0.        ,  0.13888567]),
#  'ngaiblfrec-psuipoekwei/inputs/cosmos': mhqeeomhurupxgow.py.Isovisc,
#  'auqoeigrei-huupsswoich/inputs/f': 0.6,
#  'ghoatrsfuagh-ceebaayua/outputs/count': array([   0, 1000], dtype=int32),
#  'pruzeobruu-oaflaohaek/typeHash': 100175068238429420833077061383123783763,
#  'oegaiskoch-uocaaeifra/instanceHash': 272275109288151108911050684959291276417,
#  'chauwskouc-ousfavaang/outputs/count': array([1000], dtype=int32),
#  'bukweaglao-oefriouofii/traversee': 'eigraaflausw-aatweuoastoo',
#  'uziiiesfuo-aomaitraeb/inputs/state': <everest.builts.states._threshold.Threshold at 0x7f8bcbdab128>,
#  'uafliueitrou-wreasngregl/outputs/temperatureDotField': array([[[   0.        ],
#          [   0.        ],
#          [   0.        ],
#          ...,
#          [   0.        ],
#          [   0.        ],
#          [   0.        ]],
#
#         [[   0.        ],
#          [ 159.42832331],
#          [ 141.99601707],
#          ...,
#          [ 222.33468477],
#          [-112.46856084],
#          [   0.        ]]]),
#  'uziiiesfuo-aomaitraeb/_iterator_initialise': False,
#  'oagaiengui-atsuascieg/traversee': 'jaokngoatr-eafoapraitz',
#  'uziiiesfuo-aomaitraeb/hashID': 'uziiiesfuo-aomaitraeb',
#  'kuekjoigh-toaxrhauth/outputs/chron': array([ 0.        ,  0.04771701]),
#  'bliurhsloez-sliaxphul/inputsHash': 295315159998681927389489981634367565897,
#  'moebleaswua-uakrxeiz/_iterator_initialise': False,
#  'shaadwiupo-jeaphsteapr/inputs/res': 32,
#  'azhefleudr-snipotzaa/inputs/res': 32,
#  'azhefleudr-snipotzaa/hashID': 'azhefleudr-snipotzaa',
#  'xuiklnousl-tiosrhaap/inputs/res': 32,
#  'wreanoigrou-briesnutuu/inputs/temperatureDotField': <uyiperdvjmmevonn.py.Constant at 0x7f8bcbd811d0>,
#  'iiloeugroi-ouswaisoasw/typeHash': 277512443600939600534146158745604118014,
#  'kuekjoigh-toaxrhauth/stamps': [('kuekjoigh-toaxrhauth', 0),
#   ('xeoxstiutr-eibroatsuubl', 1000)],
#  'ueguifuifr-plaejtraic/outputs/count': array([1000], dtype=int32),
#  'uziiiesfuo-aomaitraeb/inputsHash': 61010140404304158978638004143817340025,
#  'eigraaflausw-aatweuoastoo/stamps': [('eigraaflausw-aatweuoastoo', 0),
#   ('xeoxstiutr-eibroatsuubl', 1000)],
#  'kwooheagr-wriishuarhei/_iterator_initialise': False,
#  'kiaghgruosk-aidrueiutwoe/traversee': 'kuekjoigh-toaxrhauth',
#  'kwooheagr-wriishuarhei/class': planetengine._traverse.Traverse,
#  'ghoatrsfuagh-ceebaayua/outputs/temperatureDotField': array([[[ 0.        ],
#          [ 0.        ],
#          [ 0.        ],
#          ...,
#          [ 0.        ],
#          [ 0.        ],
#          [ 0.        ]],
#
#         [[ 0.        ],
#          [ 0.07025815],
#          [ 0.06605913],
#          ...,
#          [-0.06764901],
#          [-0.07114451],
#          [ 0.        ]]]),
#  'daescbluid-yeaspkruach/inputs/res': 32,
#  'xuiklnousl-tiosrhaap/inputs/temperatureField': <cpnpnxkqurwstzlf.py.Sinusoidal at 0x7f8bcbd56588>,
#  'eigleuopii-ariiglaest/inputs/temperatureDotField': <uznbslghvnachdmq.py.Constant at 0x7f8bcbf5eda0>,
#  'jaokngoatr-eafoapraitz/instanceHash': 229940007992834915840756591234947196444,
#  'keatoaque-aatzoueisnou/class': planetengine._traverse.Traverse,
#  'xeoxstiutr-eibroatsuubl/hashID': 'xeoxstiutr-eibroatsuubl',
#  'ioklougiest-duangaakwii/outputs/count': array([1000], dtype=int32),
#  'choqooxie-ioskuilaips/hashID': 'choqooxie-ioskuilaips',
#  'swahkwaefl-fuuzhoaghi/inputs/res': 32,
#  'kwooheagr-wriishuarhei/typeHash': 277512443600939600534146158745604118014,
#  'ueguifuifr-plaejtraic/inputsHash': 335456312141824655051107429006395717212,
#  'bliurhsloez-sliaxphul/inputs/aspect': 1.0,
#  'thiigriiwiu-psoesnutzeo/inputs/cosmos': rltqpgyfcbwfwswl.py.Isovisc,
#  'bukweaglao-oefriouofii/outputs/count': array([1000], dtype=int32),
#  'eephiablaab-chuawiasfoa/vector': 51683939670968405261874283733260059836,
#  'plafruonee-qefleifoa/instanceHash': 37358371631900613352929531181454096045,
#  'guoxgruf-naorhsluid/inputsHash': 154356942959006760323640183020003079571,
#  'auqiuuozau-sweadrpriasw/instanceHash': 121506700551835212172277778486864736410,
#  'keatoaque-aatzoueisnou/vector': 207125089652118702309823601305800979313,
#  'easmoaiikai-leaslpsiutw/inputs/temperatureDotField': <fivbaqwzfpgzdotb.py.Constant at 0x7f8bcbf53a20>,
#  'eikroaprubr-uiteoetreu/inputs/state': <everest.builts.states._threshold.Threshold at 0x7f8bcbf76860>,
#  'hazhuuskou-kwuaplauzhau/typeHash': 68659987862368199653950339309512250227,
#  'oukwaithiugh-giosmiasho/inputs/f': 0.6,
#  'uziiiesfuo-aomaitraeb/traversee': 'ihuotwuath-eeyaidwuik',
#  'eigleuopii-ariiglaest/outputs/temperatureDotField': array([[[   0.        ],
#          [   0.        ],
#          [   0.        ],
#          ...,
#          [   0.        ],
#          [   0.        ],
#          [   0.        ]],
#
#         [[   0.        ],
#          [-193.9027811 ],
#          [-483.25721082],
#          ...,
#          [-272.28193667],
#          [ -74.39297453],
#          [   0.        ]]]),
#  'iopliiaupseu-jioblscuir/outputs/chron': array([ 0.        ,  0.01599864]),
#  'fluokblaep-wruowstiakw/inputs/cosmos': bbtoxqaligroppcl.py.Isovisc,
#  'fluokblaep-wruowstiakw/inputs/Ra': 31622.776601683792,
#  'oephaokwaosp-uogloespezh/traversee': 'iopliiaupseu-jioblscuir',
#  'daattzoin-vispupei/class': planetengine._traverse.Traverse,
#  'xuiklnousl-tiosrhaap/inputs/Ra': 100000.0,
#  'kwoimdian-oujiusweesp/_iterator_initialise': False,
#  'shaadwiupo-jeaphsteapr/outputs/temperatureField': array([[[ 1.        ],
#          [ 0.94914657],
#          [ 0.89848194],
#          ...,
#          [ 0.10151806],
#          [ 0.05085343],
#          [ 0.        ]],
#
#         [[ 1.        ],
#          [ 0.43830799],
#          [ 0.25498289],
#          ...,
#          [ 0.62885377],
#          [ 0.44336967],
#          [ 0.        ]]]),
#  'preiphiukei-rhablgroigr/inputs/res': 32,
#  'beakgoabr-eezuiougrio/inputs/Ra': 316227.7660168379,
#  'uziiiesfuo-aomaitraeb/vector': 147180653680850119693088424594702530577,
#  'aitiafief-eafieomai/inputs/Ra': 1000000.0,
#  'iopliiaupseu-jioblscuir/instanceHash': 83324812816365006679632614455442980168,
#  'etwuinuufr-easnianeogr/typeHash': 100175068238429420833077061383123783763,
#  'daattzoin-vispupei/inputs/res': 32,
#  'ioklougiest-duangaakwii/inputs/Ra': 316227.7660168379,
#  'ngaiblfrec-psuipoekwei/vector': 2365266042769933849933473422024643353,
#  'preiphiukei-rhablgroigr/inputs/temperatureField': <kbnbesomwaekprqd.py.Sinusoidal at 0x7f8bcbe2c630>,
#  'azhefleudr-snipotzaa/instanceHash': 115833209888532313558984073849859225155,
#  'kwooheagr-wriishuarhei/outputs/count': array([1000], dtype=int32),
#  'idroiphaifl-pleakroejee/hashID': 'idroiphaifl-pleakroejee',
#  'guoxgruf-naorhsluid/_iterator_initialise': False,
#  'kwoimdian-oujiusweesp/class': planetengine._traverse.Traverse,
#  'pruzeobruu-oaflaohaek/outputs/temperatureDotField': array([[[   0.        ],
#          [   0.        ],
#          [   0.        ],
#          ...,
#          [   0.        ],
#          [   0.        ],
#          [   0.        ]],
#
#         [[   0.        ],
#          [ 121.43580709],
#          [ 100.66305328],
#          ...,
#          [-130.45879767],
#          [-142.00241337],
#          [   0.        ]]]),
#  'looprbaeng-goozhfroim/inputsHash': 236165562889714654698433235670067722039,
#  'uziiiesfuo-aomaitraeb/inputs/cosmos': cgiuveafukjsznxq.py.Isovisc,
#  'idroiphaifl-pleakroejee/inputs/res': 32,
#  'eephiablaab-chuawiasfoa/typeHash': 277512443600939600534146158745604118014,
#  'uafliueitrou-wreasngregl/inputs/res': 32,
#  'daattzoin-vispupei/_iterator_initialise': False,
#  'eigraaflausw-aatweuoastoo/instanceHash': 208189638355074232975474752015033498613,
#  'jakwouplu-puetcoav/traversee': 'oukwaithiugh-giosmiasho',
#  'oegaiskoch-uocaaeifra/inputs/aspect': 1.0,
#  'pruubpruip-twuefpriasc/inputs/aspect': 1.0,
#  'eigleuopii-ariiglaest/stamps': [('eigleuopii-ariiglaest', 0),
#   ('xeoxstiutr-eibroatsuubl', 1000)],
#  'jakwouplu-puetcoav/inputs/express': True,
#  'euteiaiyae-blaugrslouw/inputs/Ra': 31622.776601683792,
#  'guoxgruf-naorhsluid/class': planetengine._traverse.Traverse,
#  'chauwskouc-ousfavaang/typeHash': 277512443600939600534146158745604118014,
#  'kiaghgruosk-aidrueiutwoe/inputs/res': 32,
#  'dwuiscuikwua-spiopfrikw/_iterator_initialise': False,
#  'iiloeugroi-ouswaisoasw/_iterator_initialise': False,
#  'auqoeigrei-huupsswoich/inputs/express': True,
#  'iuswuithiif-roosckweabl/inputs/state': <everest.builts.states._threshold.Threshold at 0x7f8bcbf021d0>,
#  'uasfiougroa-aokliitreabl/instanceHash': 277544335528099985687361495351098502191,
#  'gloifaoree-juayzeidr/outputs/count': array([   0, 1000], dtype=int32),
#  'pheeklphiatz-rouspeits/inputs/Ra': 100000.0,
#  'oagaiengui-atsuascieg/inputsHash': 32853384938798370657824942320539275107,
#  'wuusktiedr-tsuadsciekw/inputs/temperatureDotField': <cbatqzhwrxehlero.py.Constant at 0x7f8bcbd8d208>,
#  'eigraaflausw-aatweuoastoo/typeHash': 100175068238429420833077061383123783763,
#  'kiaghgruosk-aidrueiutwoe/typeHash': 277512443600939600534146158745604118014,
#  'daescbluid-yeaspkruach/_iterator_initialise': False,
#  'chauwskouc-ousfavaang/traversee': 'troarhflux-kwetsskuakw',
#  'troarhflux-kwetsskuakw/outputs/temperatureField': array([[[ 1.        ],
#          [ 0.94914657],
#          [ 0.89848194],
#          ...,
#          [ 0.10151806],
#          [ 0.05085343],
#          [ 0.        ]],
#
#         [[ 1.        ],
#          [ 0.62803981],
#          [ 0.39199287],
#          ...,
#          [ 0.57438839],
#          [ 0.34796065],
#          [ 0.        ]]]),
#  'thaaflviusp-ixaufliust/inputs/f': 0.6,
#  'iopliiaupseu-jioblscuir/stamps': [('iopliiaupseu-jioblscuir', 0),
#   ('xeoxstiutr-eibroatsuubl', 1000)],
#  'sibaiyea-iebrubliic/inputs/value': 0.0,
#  'troarhflux-kwetsskuakw/typeHash': 100175068238429420833077061383123783763,
#  'uweoausk-waimieshoi/outputs/temperatureDotField': array([[[ 0.        ],
#          [ 0.        ],
#          [ 0.        ],
#          ...,
#          [ 0.        ],
#          [ 0.        ],
#          [ 0.        ]],
#
#         [[ 0.        ],
#          [-0.01437391],
#          [-0.0237529 ],
#          ...,
#          [ 0.01995565],
#          [ 0.01220861],
#          [ 0.        ]]]),
#  'qeibswuuwr-thoulspipr/inputs/aspect': 1.0,
#  'kuekjoigh-toaxrhauth/inputs/res': 32,
#  'choqooxie-ioskuilaips/inputs/cosmos': bggpvobaosirnibx.py.Isovisc,
#  'ngoishwruedr-snaotaamia/inputs/Ra': 1000000.0,
#  'swahkwaefl-fuuzhoaghi/inputs/Ra': 10000.0,
#  'fiubrpsuek-soanfiey/class': planetengine._traverse.Traverse,
#  'euteiaiyae-blaugrslouw/inputs/state': <everest.builts.states._threshold.Threshold at 0x7f8bcbf84400>,
#  'hazhuuskou-kwuaplauzhau/anon/checkedOut': [],
#  'jaokngoatr-eafoapraitz/inputsHash': 321804062286701081454551772245015936739,
#  'moebleaswua-uakrxeiz/vector': 114376224404368099975245152677862467187,
#  'eigleuopii-ariiglaest/inputs/temperatureField': <rhaqwgjcmiblxlgn.py.Sinusoidal at 0x7f8bcbf5ebe0>,
#  'laetzgroofl-ngiriobii/inputs/res': 32,
#  'keatoaque-aatzoueisnou/traversee': 'grazhrheong-aaviobriekl',
#  'fluokblaep-wruowstiakw/hashID': 'fluokblaep-wruowstiakw',
#  'eigleuopii-ariiglaest/hashID': 'eigleuopii-ariiglaest',
#  'laetzgroofl-ngiriobii/inputs/Ra': 100000.0,
#  'ngoishwruedr-snaotaamia/hashID': 'ngoishwruedr-snaotaamia',
#  'oufriabuigr-spiatwwioch/inputs/aspect': 1.0,
#  'chieslkeut-iogoaasma/inputs/Ra': 3162.2776601683795,
#  'uweoausk-waimieshoi/inputs/Ra': 10000.0,
#  'dwuiscuikwua-spiopfrikw/vector': 242658252457683324867035308727889980653,
#  'uuwiiskeedw-oafleuuezhue/inputs/urey': 0.0,
#  'jakwouplu-puetcoav/hashID': 'jakwouplu-puetcoav',
#  'auqiuuozau-sweadrpriasw/inputs/urey': 0.0,
#  'pruubpruip-twuefpriasc/inputs/temperatureDotField': <ewzwienfucyiqmty.py.Constant at 0x7f8bcbe36668>,
#  'bukweaglao-oefriouofii/inputsHash': 268781774508172530226094984819971142203,
#  'fluokblaep-wruowstiakw/inputs/res': 32,
#  'chieslkeut-iogoaasma/hashID': 'chieslkeut-iogoaasma',
#  'bliurhsloez-sliaxphul/stamps': [('bliurhsloez-sliaxphul', 0),
#   ('xeoxstiutr-eibroatsuubl', 1000)],
#  'xuiklnousl-tiosrhaap/inputs/f': 0.9,
#  'iuswuithiif-roosckweabl/inputs/cosmos': fjjyjuflngqelmil.py.Isovisc,
#  'azhefleudr-snipotzaa/inputs/state': <everest.builts.states._threshold.Threshold at 0x7f8bcbfc2828>,
#  'oegaiskoch-uocaaeifra/inputs/res': 32,
#  'keatoaque-aatzoueisnou/inputsHash': 47126118075924822283471945077184202405,
#  'uafliueitrou-wreasngregl/stamps': [('uafliueitrou-wreasngregl', 0),
#   ('xeoxstiutr-eibroatsuubl', 1000)],
#  'looprbaeng-goozhfroim/outputs/temperatureField': array([[[ 1.        ],
#          [ 0.94914657],
#          [ 0.89848194],
#          ...,
#          [ 0.10151806],
#          [ 0.05085343],
#          [ 0.        ]],
#
#         [[ 1.        ],
#          [ 0.3735617 ],
#          [ 0.32052189],
#          ...,
#          [ 0.6591422 ],
#          [ 0.57074285],
#          [ 0.        ]]]),
#  'shaciipsie-iadriieejui/inputs/cosmos': jddubuemrlgegofc.py.Isovisc,
#  'kwoimdian-oujiusweesp/outputs/count': array([1000], dtype=int32),
#  'jakwouplu-puetcoav/inputs/f': 0.6,
#  'daescbluid-yeaspkruach/inputs/cosmos': tvqcguefuuogggrb.py.Isovisc,
#  'plafruonee-qefleifoa/outputs/temperatureField': array([[[ 1.        ],
#          [ 0.94914657],
#          [ 0.89848194],
#          ...,
#          [ 0.10151806],
#          [ 0.05085343],
#          [ 0.        ]],
#
#         [[ 1.        ],
#          [ 0.43922486],
#          [ 0.25867521],
#          ...,
#          [ 0.63505035],
#          [ 0.45791006],
#          [ 0.        ]]]),
#  'oufriabuigr-spiatwwioch/instanceHash': 260050024047494779761873139064018847228,
#  'ihuotwuath-eeyaidwuik/instanceHash': 252486509788025316932728866702422023249,
#  'jaokngoatr-eafoapraitz/inputs/aspect': 1.0,
#  'heikspiic-oevouiima/vector': 131759314329846700081637916045029592021,
#  'oephaokwaosp-uogloespezh/class': planetengine._traverse.Traverse,
#  'plafruonee-qefleifoa/inputs/res': 32,
#  'jaokngoatr-eafoapraitz/inputs/urey': 0.0,
#  'eigraaflausw-aatweuoastoo/inputsHash': 148106742980921332753336039283191720714,
#  'jaokngoatr-eafoapraitz/outputs/temperatureDotField': array([[[ 0.        ],
#          [ 0.        ],
#          [ 0.        ],
#          ...,
#          [ 0.        ],
#          [ 0.        ],
#          [ 0.        ]],
#
#         [[ 0.        ],
#          [ 0.03705652],
#          [ 0.06086968],
#          ...,
#          [-0.25416766],
#          [-0.1313023 ],
#          [ 0.        ]]]),
#  'eephiablaab-chuawiasfoa/traversee': 'eigleuopii-ariiglaest',
#  'plafruonee-qefleifoa/outputs/chron': array([ 0.        ,  0.03605252]),
#  'jaokngoatr-eafoapraitz/outputs/temperatureField': array([[[ 1.        ],
#          [ 0.94914657],
#          [ 0.89848194],
#          ...,
#          [ 0.10151806],
#          [ 0.05085343],
#          [ 0.        ]],
#
#         [[ 1.        ],
#          [ 0.79676421],
#          [ 0.61624061],
#          ...,
#          [ 0.24589097],
#          [ 0.12587746],
#          [ 0.        ]]]),
#  'ihuotwuath-eeyaidwuik/inputsHash': 147180653680850119693088424594702530577,
#  'chieslkeut-iogoaasma/class': ndonnpeldklzyrac.py.Isovisc,
#  'fluokblaep-wruowstiakw/inputs/express': True,
#  'uuwiiskeedw-oafleuuezhue/inputs/aspect': 1.0,
#  'guoxgruf-naorhsluid/traversee': 'uweoausk-waimieshoi',
#  'thiigriiwiu-psoesnutzeo/instanceHash': 21532659235114580197751675181320152646,
#  'etwuinuufr-easnianeogr/inputs/urey': 0.0,
#  'fiubrpsuek-soanfiey/inputs/express': True,
#  'shaadwiupo-jeaphsteapr/inputsHash': 188805645040548916251073544465607878267,
#  'bliurhsloez-sliaxphul/outputs/chron': array([ 0.        ,  0.07452821]),
#  'moebleaswua-uakrxeiz/instanceHash': 182106875768097151567872105122060855342,
#  'uweoausk-waimieshoi/stamps': [('uweoausk-waimieshoi', 0),
#   ('xeoxstiutr-eibroatsuubl', 1000)],
#  'idroiphaifl-pleakroejee/outputs/chron': array([ 0.        ,  0.06272849]),
#  'bliurhsloez-sliaxphul/inputs/res': 32,
#  'wuusktiedr-tsuadsciekw/inputs/aspect': 1.0,
#  'qeibswuuwr-thoulspipr/inputs/temperatureField': <waamfhtwhpzevgfb.py.Sinusoidal at 0x7f8bcbe48a58>,
#  'aitiafief-eafieomai/class': planetengine._traverse.Traverse,
#  'auqiuuozau-sweadrpriasw/inputs/temperatureDotField': <tztxaxrqjfqbfsxu.py.Constant at 0x7f8bcbfa1fd0>,
#  'aitiafief-eafieomai/vector': 99085955928906296332257490963966454026,
#  'oagaiengui-atsuascieg/hashID': 'oagaiengui-atsuascieg',
#  'euteiaiyae-blaugrslouw/inputs/res': 32,
#  'iuswuithiif-roosckweabl/inputs/Ra': 316227.7660168379,
#  'shaadwiupo-jeaphsteapr/outputs/chron': array([ 0.        ,  0.03087492]),
#  'uweoausk-waimieshoi/inputs/temperatureDotField': <lguvzqxkpyjhkblu.py.Constant at 0x7f8bcbda4da0>,
#  'azhefleudr-snipotzaa/typeHash': 277512443600939600534146158745604118014,
#  'uafliueitrou-wreasngregl/inputs/temperatureDotField': <uajcpfvkiepokjsx.py.Constant at 0x7f8bcbe02a20>,
#  'kwoimdian-oujiusweesp/inputsHash': 209970799888217909334305263342208990967,
#  'iopliiaupseu-jioblscuir/outputs/temperatureDotField': array([[[   0.        ],
#          [   0.        ],
#          [   0.        ],
#          ...,
#          [   0.        ],
#          [   0.        ],
#          [   0.        ]],
#
#         [[   0.        ],
#          [-204.50675332],
#          [ -87.47995159],
#          ...,
#          [ -10.84720398],
#          [  26.91814023],
#          [   0.        ]]]),
#  'kuekjoigh-toaxrhauth/hashID': 'kuekjoigh-toaxrhauth',
#  'idroiphaifl-pleakroejee/inputs/temperatureField': <korygdjnptagdgig.py.Sinusoidal at 0x7f8bcbea4588>,
#  'kuekjoigh-toaxrhauth/class': inqaruyvuooyuntp.py.Isovisc,
#  'qeibswuuwr-thoulspipr/inputs/f': 0.9,
#  'easmoaiikai-leaslpsiutw/outputs/count': array([   0, 1000], dtype=int32),
#  'choqooxie-ioskuilaips/instanceHash': 104059875500065781281045052522857744771,
#  'hazhuuskou-kwuaplauzhau/inputs/f': [0.5, 0.6, 0.7, 0.8, 0.9, 1.0],
#  'iopliiaupseu-jioblscuir/hashID': 'iopliiaupseu-jioblscuir',
#  'uuwiiskeedw-oafleuuezhue/outputs/temperatureDotField': array([[[ 0.        ],
#          [ 0.        ],
#          [ 0.        ],
#          ...,
#          [ 0.        ],
#          [ 0.        ],
#          [ 0.        ]],
#
#         [[ 0.        ],
#          [-0.2503028 ],
#          [-0.30675124],
#          ...,
#          [ 0.01478837],
#          [ 0.0595986 ],
#          [ 0.        ]]]),
#  'looprbaeng-goozhfroim/outputs/temperatureDotField': array([[[  0.        ],
#          [  0.        ],
#          [  0.        ],
#          ...,
#          [  0.        ],
#          [  0.        ],
#          [  0.        ]],
#
#         [[  0.        ],
#          [-55.43080959],
#          [-74.99745769],
#          ...,
#          [-26.06543291],
#          [-34.48268162],
#          [  0.        ]]]),
#  'plafruonee-qefleifoa/inputs/urey': 0.0,
#  'beakgoabr-eezuiougrio/inputs/temperatureDotField': <yovugkqcwbjvbnta.py.Constant at 0x7f8bcbfc2cc0>,
#  'chieslkeut-iogoaasma/outputs/temperatureField': array([[[ 1.        ],
#          [ 0.94914657],
#          [ 0.89848194],
#          ...,
#          [ 0.10151806],
#          [ 0.05085343],
#          [ 0.        ]],
#
#         [[ 1.        ],
#          [ 0.83823032],
#          [ 0.68817493],
#          ...,
#          [ 0.31160841],
#          [ 0.16164958],
#          [ 0.        ]]]),
#  'preiphiukei-rhablgroigr/instanceHash': 100539671770287615284539997378606942557,
#  'ihuotwuath-eeyaidwuik/stamps': [('ihuotwuath-eeyaidwuik', 0),
#   ('xeoxstiutr-eibroatsuubl', 1000)],
#  'chauwskouc-ousfavaang/_iterator_initialise': False,
#  'guoxgruf-naorhsluid/inputs/res': 32,
#  'oufriabuigr-spiatwwioch/inputs/Ra': 1000000.0,
#  'idroiphaifl-pleakroejee/outputs/temperatureField': array([[[ 1.        ],
#          [ 0.94914657],
#          [ 0.89848194],
#          ...,
#          [ 0.10151806],
#          [ 0.05085343],
#          [ 0.        ]],
#
#         [[ 1.        ],
#          [ 0.58738091],
#          [ 0.33589249],
#          ...,
#          [ 0.50898893],
#          [ 0.3018462 ],
#          [ 0.        ]]]),
#  'guoxgruf-naorhsluid/inputs/express': True,
#  'thaaflviusp-ixaufliust/instanceHash': 19077681684357954911534465930227530041,
#  'ihuotwuath-eeyaidwuik/inputs/temperatureField': <khubcagaurwypgrh.py.Sinusoidal at 0x7f8bcbea4eb8>,
#  'uasfiougroa-aokliitreabl/inputs/aspect': 1.0,
#  'jakwouplu-puetcoav/typeHash': 277512443600939600534146158745604118014,
#  'oegaiskoch-uocaaeifra/inputs/temperatureDotField': <qpjgixuspjgrxnzj.py.Constant at 0x7f8bcbe73ba8>,
#  'kuekjoigh-toaxrhauth/instanceHash': 216684402490296769873685089018675573700,
#  'iiloeugroi-ouswaisoasw/instanceHash': 119867376579392636327594354727947461737,
#  'uuwiiskeedw-oafleuuezhue/inputs/temperatureField': <zjdnvaeqwktigmsi.py.Sinusoidal at 0x7f8bcbd99400>,
#  'daattzoin-vispupei/inputs/cosmos': kxgtswpxdmmzyxhd.py.Isovisc,
#  'guoxgruf-naorhsluid/typeHash': 277512443600939600534146158745604118014,
#  'easmoaiikai-leaslpsiutw/class': rlthorfvemmbjbuh.py.Isovisc,
#  'preiphiukei-rhablgroigr/typeHash': 100175068238429420833077061383123783763,
#  'chauwskouc-ousfavaang/inputs/state': <everest.builts.states._threshold.Threshold at 0x7f8bcbfe5160>,
#  'qeibswuuwr-thoulspipr/outputs/temperatureField': array([[[ 1.        ],
#          [ 0.94914657],
#          [ 0.89848194],
#          ...,
#          [ 0.10151806],
#          [ 0.05085343],
#          [ 0.        ]],
#
#         [[ 1.        ],
#          [ 0.51040763],
#          [ 0.38226027],
#          ...,
#          [ 0.56849482],
#          [ 0.43199619],
#          [ 0.        ]]]),
#  'choqooxie-ioskuilaips/traversee': 'xuiklnousl-tiosrhaap',
#  'looprbaeng-goozhfroim/inputs/urey': 0.0,
#  'kuekjoigh-toaxrhauth/inputs/Ra': 100000.0,
#  'iopliiaupseu-jioblscuir/inputsHash': 25105640842883471258002476494324776422,
#  'guoxgruf-naorhsluid/vector': 299847077041860033442636766223991901175,
#  'wuusktiedr-tsuadsciekw/inputs/temperatureField': <mafbaoejgtlsksty.py.Sinusoidal at 0x7f8bcbd8d518>,
#  'pruubpruip-twuefpriasc/outputs/temperatureDotField': array([[[ 0.        ],
#          [ 0.        ],
#          [ 0.        ],
#          ...,
#          [ 0.        ],
#          [ 0.        ],
#          [ 0.        ]],
#
#         [[ 0.        ],
#          [-0.005787  ],
#          [-0.0113778 ],
#          ...,
#          [-0.03181781],
#          [-0.01696921],
#          [ 0.        ]]]),
#  'ioklougiest-duangaakwii/inputs/express': True,
#  'auqoeigrei-huupsswoich/inputsHash': 67783316886389605168273272358783627045,
#  'aitiafief-eafieomai/_iterator_initialise': False,
#  'eikroaprubr-uiteoetreu/traversee': 'pruubpruip-twuefpriasc',
#  'preiphiukei-rhablgroigr/inputs/temperatureDotField': <rkzkommsegxluitj.py.Constant at 0x7f8bcbe2c4a8>,
#  'moebleaswua-uakrxeiz/inputs/cosmos': gwzdjpenngcqpfde.py.Isovisc,
#  'wuusktiedr-tsuadsciekw/stamps': [('wuusktiedr-tsuadsciekw', 0),
#   ('xeoxstiutr-eibroatsuubl', 1000)],
#  'ueguifuifr-plaejtraic/traversee': 'oufriabuigr-spiatwwioch',
#  'daescbluid-yeaspkruach/hashID': 'daescbluid-yeaspkruach',
#  'swahkwaefl-fuuzhoaghi/inputsHash': 309229814863570652830851214648027037456,
#  'chieslkeut-iogoaasma/inputsHash': 252091676670554604123800752883265978028,
#  'thiigriiwiu-psoesnutzeo/vector': 256921108055274523160608350261386833117,
#  'ngoishwruedr-snaotaamia/stamps': [('ngoishwruedr-snaotaamia', 0),
#   ('xeoxstiutr-eibroatsuubl', 1000)],
#  'iopliiaupseu-jioblscuir/class': hxybcaxlgduhojwk.py.Isovisc,
#  'choqooxie-ioskuilaips/typeHash': 277512443600939600534146158745604118014,
#  'kwoimdian-oujiusweesp/inputs/Ra': 1000000.0,
#  'fiubrpsuek-soanfiey/_iterator_initialise': False,
#  'chieslkeut-iogoaasma/inputs/aspect': 1.0,
#  'euteiaiyae-blaugrslouw/instanceHash': 44019597294330109416271994713335889037,
#  'grazhrheong-aaviobriekl/inputs/Ra': 10000.0,
#  'auqiuuozau-sweadrpriasw/stamps': [('auqiuuozau-sweadrpriasw', 0),
#   ('xeoxstiutr-eibroatsuubl', 1000)],
#  'auqoeigrei-huupsswoich/inputs/state': <everest.builts.states._threshold.Threshold at 0x7f8bcbfb57b8>,
#  'moebleaswua-uakrxeiz/traversee': 'uasfiougroa-aokliitreabl',
#  'grazhrheong-aaviobriekl/inputs/f': 1.0,
#  'choqooxie-ioskuilaips/inputs/express': True,
#  'choqooxie-ioskuilaips/class': planetengine._traverse.Traverse,
#  'beakgoabr-eezuiougrio/inputs/temperatureField': <pzpkriioqixiszcd.py.Sinusoidal at 0x7f8bcbfc2eb8>,
#  'swahkwaefl-fuuzhoaghi/_iterator_initialise': False,
#  'azhefleudr-snipotzaa/traversee': 'chieslkeut-iogoaasma',
#  'pruubpruip-twuefpriasc/class': rhwkygmzrafzdtzl.py.Isovisc,
#  'pruubpruip-twuefpriasc/typeHash': 100175068238429420833077061383123783763,
#  'shaadwiupo-jeaphsteapr/inputs/aspect': 1.0,
#  'laetzgroofl-ngiriobii/inputs/temperatureDotField': <lheljwaubxdxqady.py.Constant at 0x7f8bcbe82978>,
#  'oagaiengui-atsuascieg/inputs/express': True,
#  'hazhuuskou-kwuaplauzhau/anon/checkedBack': [],
#  'ngaiblfrec-psuipoekwei/inputs/f': 0.5,
#  'euteiaiyae-blaugrslouw/_iterator_initialise': False,
#  'heikspiic-oevouiima/inputs/res': 32,
#  'etwuinuufr-easnianeogr/inputs/res': 32,
#  'ioklougiest-duangaakwii/inputs/cosmos': axblxylfbjieselu.py.Isovisc,
#  'uweoausk-waimieshoi/outputs/count': array([   0, 1000], dtype=int32),
#  'oagaiengui-atsuascieg/inputs/Ra': 3162.2776601683795,
#  'uasfiougroa-aokliitreabl/outputs/chron': array([ 0.        ,  0.01300772]),
#  'shaadwiupo-jeaphsteapr/stamps': [('shaadwiupo-jeaphsteapr', 0),
#   ('xeoxstiutr-eibroatsuubl', 1000)],
#  'pruzeobruu-oaflaohaek/inputs/temperatureDotField': <utmxotbudpimvmkg.py.Constant at 0x7f8bcbe36c50>,
#  'qeibswuuwr-thoulspipr/hashID': 'qeibswuuwr-thoulspipr',
#  'xeoxstiutr-eibroatsuubl/inputs/rounding': None,
#  'pruubpruip-twuefpriasc/inputs/temperatureField': <obtqwjvocikxxnft.py.Sinusoidal at 0x7f8bcbe36828>,
#  'iiloeugroi-ouswaisoasw/traversee': 'looprbaeng-goozhfroim',
#  'uasfiougroa-aokliitreabl/inputs/temperatureField': <frndlddltznuynzo.py.Sinusoidal at 0x7f8bcbe0aba8>,
#  'eigraaflausw-aatweuoastoo/outputs/temperatureField': array([[[ 1.        ],
#          [ 0.94914657],
#          [ 0.89848194],
#          ...,
#          [ 0.10151806],
#          [ 0.05085343],
#          [ 0.        ]],
#
#         [[ 1.        ],
#          [ 0.43185514],
#          [ 0.24481403],
#          ...,
#          [ 0.50303724],
#          [ 0.34093893],
#          [ 0.        ]]]),
#  'preiphiukei-rhablgroigr/hashID': 'preiphiukei-rhablgroigr',
#  'thiigriiwiu-psoesnutzeo/inputs/res': 32,
#  'uuwiiskeedw-oafleuuezhue/inputs/f': 0.8,
#  'pruubpruip-twuefpriasc/stamps': [('pruubpruip-twuefpriasc', 0),
#   ('xeoxstiutr-eibroatsuubl', 1000)],
#  'eikroaprubr-uiteoetreu/typeHash': 277512443600939600534146158745604118014,
# ...
#          [  0.00000000e+00],
#          [  0.00000000e+00],
#          ...,
#          [  0.00000000e+00],
#          [  0.00000000e+00],
#          [  0.00000000e+00]],
#
#         [[  0.00000000e+00],
#          [  3.83694856e-05],
#          [ -1.97248706e-04],
#          ...,
#          [ -1.12568339e-02],
#          [ -5.91811095e-03],
#          [  0.00000000e+00]]]),
#  'fiubrpsuek-soanfiey/typeHash': 277512443600939600534146158745604118014,
#  'oegaiskoch-uocaaeifra/outputs/temperatureField': array([[[ 1.        ],
#          [ 0.94914657],
#          [ 0.89848194],
#          ...,
#          [ 0.10151806],
#          [ 0.05085343],
#          [ 0.        ]],
#
#         [[ 1.        ],
#          [ 0.70119092],
#          [ 0.46603772],
#          ...,
#          [ 0.34495996],
#          [ 0.18451529],
#          [ 0.        ]]]),
#  'doaflophuo-oumjaeg/inputs/cosmos': fqnzztwupjfueelu.py.Isovisc,
#  'uweoausk-waimieshoi/hashID': 'uweoausk-waimieshoi',
#  'beakgoabr-eezuiougrio/hashID': 'beakgoabr-eezuiougrio',
#  'kwooheagr-wriishuarhei/inputs/express': True,
#  'thaaflviusp-ixaufliust/inputs/Ra': 31622.776601683792,
#  'bliurhsloez-sliaxphul/hashID': 'bliurhsloez-sliaxphul',
#  'daattzoin-vispupei/outputs/count': array([1000], dtype=int32),
#  'looprbaeng-goozhfroim/inputs/aspect': 1.0,
#  'azhefleudr-snipotzaa/inputs/f': 1.0,
#  'kriobrusmuu-fruetzswuips/inputsHash': 169833922617900939057922567709225750890,
#  'oephaokwaosp-uogloespezh/inputsHash': 329442481849061678403099992580633170751,
#  'euteiaiyae-blaugrslouw/inputsHash': 269014433204194816775990162176933913722,
#  'pruubpruip-twuefpriasc/inputs/res': 32,
#  'ioklougiest-duangaakwii/_iterator_initialise': False,
#  'daattzoin-vispupei/inputs/Ra': 10000.0,
#  'kuekjoigh-toaxrhauth/inputs/urey': 0.0,
#  'beakgoabr-eezuiougrio/instanceHash': 298287751570589595884727324472797033912,
#  'oufriabuigr-spiatwwioch/outputs/count': array([   0, 1000], dtype=int32),
#  'jakwouplu-puetcoav/class': planetengine._traverse.Traverse,
#  'oephaokwaosp-uogloespezh/inputs/express': True,
#  'aitiafief-eafieomai/outputs/count': array([1000], dtype=int32),
#  'iopliiaupseu-jioblscuir/typeHash': 100175068238429420833077061383123783763,
#  'wreanoigrou-briesnutuu/inputsHash': 79150595243018692604362732810121952930,
#  'iuswuithiif-roosckweabl/_iterator_initialise': False,
#  'auqiuuozau-sweadrpriasw/inputsHash': 73311005602725546849142484130856375897,
#  'wuusktiedr-tsuadsciekw/inputs/f': 0.8,
#  'uuwiiskeedw-oafleuuezhue/inputs/res': 32,
#  'ioklougiest-duangaakwii/vector': 73311005602725546849142484130856375897,
#  'grazhrheong-aaviobriekl/outputs/count': array([   0, 1000], dtype=int32),
#  'eigleuopii-ariiglaest/outputs/chron': array([ 0.        ,  0.00941156]),
#  'chieslkeut-iogoaasma/stamps': [('chieslkeut-iogoaasma', 0),
#   ('xeoxstiutr-eibroatsuubl', 1000)],
#  'pruzeobruu-oaflaohaek/instanceHash': 229701752260375715322781372896519944240,
#  'jaokngoatr-eafoapraitz/outputs/count': array([   0, 1000], dtype=int32),
#  'jaokngoatr-eafoapraitz/inputs/f': 0.5,
#  'beakgoabr-eezuiougrio/outputs/chron': array([ 0.        ,  0.02663012]),
#  'oegaiskoch-uocaaeifra/inputsHash': 98230277481959610659272750881109472021,
#  'moebleaswua-uakrxeiz/inputs/express': True,
#  'etwuinuufr-easnianeogr/inputs/temperatureField': <gcqtvnbxgviutuze.py.Sinusoidal at 0x7f8bcbf845c0>,
#  'wuusktiedr-tsuadsciekw/outputs/chron': array([ 0.        ,  0.38571811]),
#  'thiigriiwiu-psoesnutzeo/inputs/state': <everest.builts.states._threshold.Threshold at 0x7f8bcbdf3358>,
#  'etwuinuufr-easnianeogr/outputs/chron': array([ 0.        ,  0.05791935]),
#  'beakgoabr-eezuiougrio/inputs/res': 32,
#  'uziiiesfuo-aomaitraeb/inputs/express': True,
#  'ngaiblfrec-psuipoekwei/traversee': 'etwuinuufr-easnianeogr',
#  'bukweaglao-oefriouofii/inputs/state': <everest.builts.states._threshold.Threshold at 0x7f8bcbfd6cf8>,
#  'uweoausk-waimieshoi/inputs/urey': 0.0,
#  'thaaflviusp-ixaufliust/vector': 301072065454031695667925866801605322247,
#  'ghoatrsfuagh-ceebaayua/class': tswqirhujbcoypnp.py.Isovisc,
#  'qeibswuuwr-thoulspipr/inputs/Ra': 316227.7660168379,
#  'uasfiougroa-aokliitreabl/inputs/urey': 0.0,
#  'auqiuuozau-sweadrpriasw/class': sptjbbdepxhfvtbq.py.Isovisc,
#  'thaaflviusp-ixaufliust/class': planetengine._traverse.Traverse,
#  'auqiuuozau-sweadrpriasw/inputs/temperatureField': <qggygnpjmdztkkhu.py.Sinusoidal at 0x7f8bcbfb57f0>,
#  'kuekjoigh-toaxrhauth/outputs/count': array([   0, 1000], dtype=int32),
#  'xeoxstiutr-eibroatsuubl/inputsHash': 26467322394214225184517231474489317098,
#  'uuwiiskeedw-oafleuuezhue/class': cywbyanimfbflicr.py.Isovisc,
#  'bukweaglao-oefriouofii/vector': 148106742980921332753336039283191720714,
#  'uweoausk-waimieshoi/class': jfqqjdwxbmswkqtk.py.Isovisc,
#  'hazhuuskou-kwuaplauzhau/inputs/observers': [],
#  'ngaiblfrec-psuipoekwei/inputs/res': 32,
#  'kiaghgruosk-aidrueiutwoe/instanceHash': 51737135805376692918962133929072963056,
#  'heikspiic-oevouiima/class': planetengine._traverse.Traverse,
#  'xuiklnousl-tiosrhaap/inputs/aspect': 1.0,
#  'eigleuopii-ariiglaest/inputs/urey': 0.0,
#  'kwooheagr-wriishuarhei/traversee': 'wreanoigrou-briesnutuu',
#  'idroiphaifl-pleakroejee/inputsHash': 301072065454031695667925866801605322247,
#  'daescbluid-yeaspkruach/inputsHash': 253012503026629176772093683570600272351,
#  'kwoimdian-oujiusweesp/inputs/res': 32,
#  'auqiuuozau-sweadrpriasw/outputs/temperatureField': array([[[ 1.        ],
#          [ 0.94914657],
#          [ 0.89848194],
#          ...,
#          [ 0.10151806],
#          [ 0.05085343],
#          [ 0.        ]],
#
#         [[ 1.        ],
#          [ 0.53860507],
#          [ 0.4058056 ],
#          ...,
#          [ 0.59391526],
#          [ 0.46116829],
#          [ 0.        ]]]),
#  'oukwaithiugh-giosmiasho/outputs/temperatureField': array([[[ 1.        ],
#          [ 0.94914657],
#          [ 0.89848194],
#          ...,
#          [ 0.10151806],
#          [ 0.05085343],
#          [ 0.        ]],
#
#         [[ 1.        ],
#          [ 0.71371237],
#          [ 0.48525998],
#          ...,
#          [ 0.37392239],
#          [ 0.20117019],
#          [ 0.        ]]]),
#  'uasfiougroa-aokliitreabl/typeHash': 100175068238429420833077061383123783763,
#  'doaflophuo-oumjaeg/inputs/res': 32,
#  'etwuinuufr-easnianeogr/outputs/count': array([   0, 1000], dtype=int32),
#  'wreanoigrou-briesnutuu/stamps': [('wreanoigrou-briesnutuu', 0),
#   ('xeoxstiutr-eibroatsuubl', 1000)],
#  'kiaghgruosk-aidrueiutwoe/inputs/f': 1.0,
#  'auqoeigrei-huupsswoich/typeHash': 277512443600939600534146158745604118014,
#  'wuusktiedr-tsuadsciekw/typeHash': 100175068238429420833077061383123783763,
#  'jaokngoatr-eafoapraitz/inputs/res': 32,
#  'moebleaswua-uakrxeiz/class': planetengine._traverse.Traverse,
#  'heikspiic-oevouiima/inputsHash': 36026230545082122359234701210332662263,
#  'iuswuithiif-roosckweabl/class': planetengine._traverse.Traverse,
#  'xuiklnousl-tiosrhaap/inputs/urey': 0.0,
#  'oegaiskoch-uocaaeifra/outputs/count': array([   0, 1000], dtype=int32),
#  'xuiklnousl-tiosrhaap/outputs/count': array([   0, 1000], dtype=int32),
#  'swahkwaefl-fuuzhoaghi/outputs/count': array([1000], dtype=int32),
#  'gloifaoree-juayzeidr/outputs/temperatureDotField': array([[[ 0.        ],
#          [ 0.        ],
#          [ 0.        ],
#          ...,
#          [ 0.        ],
#          [ 0.        ],
#          [ 0.        ]],
#
#         [[ 0.        ],
#          [ 0.02666285],
#          [ 0.04365572],
#          ...,
#          [-0.05455595],
#          [-0.03141889],
#          [ 0.        ]]]),
#  'uuwiiskeedw-oafleuuezhue/outputs/temperatureField': array([[[ 1.        ],
#          [ 0.94914657],
#          [ 0.89848194],
#          ...,
#          [ 0.10151806],
#          [ 0.05085343],
#          [ 0.        ]],
#
#         [[ 1.        ],
#          [ 0.61686489],
#          [ 0.37628289],
#          ...,
#          [ 0.551658  ],
#          [ 0.33188205],
#          [ 0.        ]]]),
#  'doaflophuo-oumjaeg/outputs/count': array([1000], dtype=int32),
#  'iopliiaupseu-jioblscuir/inputs/f': 0.5,
#  'shaadwiupo-jeaphsteapr/typeHash': 100175068238429420833077061383123783763,
#  'wuusktiedr-tsuadsciekw/inputs/Ra': 3162.2776601683795,
#  'daescbluid-yeaspkruach/typeHash': 277512443600939600534146158745604118014,
#  'wuusktiedr-tsuadsciekw/instanceHash': 45686359666993188743312136892279541870,
#  'eigraaflausw-aatweuoastoo/inputs/temperatureDotField': <sinpghpvyhhsmeyv.py.Constant at 0x7f8bcbf6ddd8>,
#  'uweoausk-waimieshoi/inputs/f': 0.9,
#  'ngoishwruedr-snaotaamia/inputs/urey': 0.0,
#  'auqiuuozau-sweadrpriasw/outputs/chron': array([ 0.        ,  0.04115226]),
#  'auqoeigrei-huupsswoich/inputs/Ra': 100000.0,
#  'oukwaithiugh-giosmiasho/inputs/Ra': 10000.0,
#  'uuwiiskeedw-oafleuuezhue/outputs/count': array([   0, 1000], dtype=int32),
#  'chieslkeut-iogoaasma/outputs/temperatureDotField': array([[[  0.00000000e+00],
#          [  0.00000000e+00],
#          [  0.00000000e+00],
#          ...,
#          [  0.00000000e+00],
#          [  0.00000000e+00],
#          [  0.00000000e+00]],
#
#         [[  0.00000000e+00],
#          [ -1.07226084e-05],
#          [ -1.98673180e-05],
#          ...,
#          [  1.83472104e-05],
#          [  9.93974206e-06],
#          [  0.00000000e+00]]]),
#  'oephaokwaosp-uogloespezh/vector': 25105640842883471258002476494324776422,
#  'oagaiengui-atsuascieg/_iterator_initialise': False,
#  'looprbaeng-goozhfroim/inputs/res': 32,
#  'ueguifuifr-plaejtraic/typeHash': 277512443600939600534146158745604118014,
#  'ngaiblfrec-psuipoekwei/inputsHash': 175547684091247389496582081514149641807,
#  'chauwskouc-ousfavaang/hashID': 'chauwskouc-ousfavaang',
#  'gloifaoree-juayzeidr/class': tqzeurmmpqkarzrn.py.Isovisc,
#  'ngaiblfrec-psuipoekwei/instanceHash': 10347180340403914407283086785237958652,
#  'dwuiscuikwua-spiopfrikw/hashID': 'dwuiscuikwua-spiopfrikw',
#  'kwoimdian-oujiusweesp/instanceHash': 281030313530710947296570222513502232462,
#  'thaaflviusp-ixaufliust/outputs/count': array([1000], dtype=int32),
#  'plafruonee-qefleifoa/inputs/Ra': 100000.0,
#  'hazhuuskou-kwuaplauzhau/inputs/res': 32,
#  'laetzgroofl-ngiriobii/outputs/temperatureField': array([[[ 1.        ],
#          [ 0.94914657],
#          [ 0.89848194],
#          ...,
#          [ 0.10151806],
#          [ 0.05085343],
#          [ 0.        ]],
#
#         [[ 1.        ],
#          [ 0.45948729],
#          [ 0.28088112],
#          ...,
#          [ 0.65782569],
#          [ 0.47879689],
#          [ 0.        ]]]),
#  'dwuiscuikwua-spiopfrikw/class': planetengine._traverse.Traverse,
#  'oephaokwaosp-uogloespezh/typeHash': 277512443600939600534146158745604118014,
#  'thaaflviusp-ixaufliust/hashID': 'thaaflviusp-ixaufliust',
#  'doaflophuo-oumjaeg/_iterator_initialise': False,
#  'auqoeigrei-huupsswoich/outputs/count': array([1000], dtype=int32),
#  'uasfiougroa-aokliitreabl/outputs/temperatureField': array([[[ 1.        ],
#          [ 0.94914657],
#          [ 0.89848194],
#          ...,
#          [ 0.10151806],
#          [ 0.05085343],
#          [ 0.        ]],
#
#         [[ 1.        ],
#          [ 0.27801852],
#          [ 0.29399952],
#          ...,
#          [ 0.69552915],
#          [ 0.71662303],
#          [ 0.        ]]]),
#  'doaflophuo-oumjaeg/inputs/Ra': 3162.2776601683795,
#  'idroiphaifl-pleakroejee/outputs/temperatureDotField': array([[[ 0.        ],
#          [ 0.        ],
#          [ 0.        ],
#          ...,
#          [ 0.        ],
#          [ 0.        ],
#          [ 0.        ]],
#
#         [[ 0.        ],
#          [ 3.51990883],
#          [ 4.62009998],
#          ...,
#          [-5.30634824],
#          [-3.5823079 ],
#          [ 0.        ]]]),
#  'grazhrheong-aaviobriekl/inputsHash': 207125089652118702309823601305800979313,
#  'eigleuopii-ariiglaest/inputsHash': 51683939670968405261874283733260059836,
#  'fiubrpsuek-soanfiey/traversee': 'pruzeobruu-oaflaohaek',
#  'fiubrpsuek-soanfiey/hashID': 'fiubrpsuek-soanfiey',
#  'oegaiskoch-uocaaeifra/outputs/chron': array([ 0.        ,  0.12147511]),
#  'troarhflux-kwetsskuakw/inputs/aspect': 1.0,
#  'keatoaque-aatzoueisnou/inputs/Ra': 10000.0,
#  'kriobrusmuu-fruetzswuips/inputs/pert': 0.2,
#  'kiaghgruosk-aidrueiutwoe/inputs/state': <everest.builts.states._threshold.Threshold at 0x7f8bcbe99b70>,
#  'chieslkeut-iogoaasma/inputs/temperatureDotField': <hhwteqfjasrkpwnr.py.Constant at 0x7f8bcbfed2e8>,
#  'bliurhsloez-sliaxphul/inputs/temperatureField': <pfyugueufdoiyhex.py.Sinusoidal at 0x7f8bcbfd64a8>,
#  'fluokblaep-wruowstiakw/instanceHash': 144221012944633151868260357861874987390,
#  'troarhflux-kwetsskuakw/outputs/count': array([   0, 1000], dtype=int32),
#  'euteiaiyae-blaugrslouw/traversee': 'ghoatrsfuagh-ceebaayua',
#  'shaciipsie-iadriieejui/_iterator_initialise': False,
#  'eigraaflausw-aatweuoastoo/inputs/urey': 0.0,
#  'iopliiaupseu-jioblscuir/inputs/Ra': 316227.7660168379,
#  'sibaiyea-iebrubliic/inputsHash': 324856689443627944009327383532416922470,
#  'bukweaglao-oefriouofii/inputs/res': 32,
#  'azhefleudr-snipotzaa/vector': 252091676670554604123800752883265978028,
#  'preiphiukei-rhablgroigr/outputs/temperatureField': array([[[ 1.        ],
#          [ 0.94914657],
#          [ 0.89848194],
#          ...,
#          [ 0.10151806],
#          [ 0.05085343],
#          [ 0.        ]],
#
#         [[ 1.        ],
#          [ 0.8319684 ],
#          [ 0.67693084],
#          ...,
#          [ 0.30026901],
#          [ 0.15539073],
#          [ 0.        ]]]),
#  'laetzgroofl-ngiriobii/outputs/temperatureDotField': array([[[ 0.        ],
#          [ 0.        ],
#          [ 0.        ],
#          ...,
#          [ 0.        ],
#          [ 0.        ],
#          [ 0.        ]],
#
#         [[ 0.        ],
#          [-1.40283865],
#          [-1.25014526],
#          ...,
#          [-1.32098774],
#          [-0.37283634],
#          [ 0.        ]]]),
#  'oukwaithiugh-giosmiasho/stamps': [('oukwaithiugh-giosmiasho', 0),
#   ('xeoxstiutr-eibroatsuubl', 1000)],
#  'idroiphaifl-pleakroejee/class': worogqntlchbcgmg.py.Isovisc,
#  'ihuotwuath-eeyaidwuik/inputs/temperatureDotField': <dxwzfwyfjjijjdgp.py.Constant at 0x7f8bcbea4dd8>,
#  'shaciipsie-iadriieejui/inputs/f': 0.8,
#  'kwooheagr-wriishuarhei/inputs/Ra': 3162.2776601683795,
#  'dwuiscuikwua-spiopfrikw/inputs/cosmos': bmruejgjdquqfglh.py.Isovisc,
#  'doaflophuo-oumjaeg/typeHash': 277512443600939600534146158745604118014,
#  'choqooxie-ioskuilaips/vector': 113032409169739638612062685138239979105,
#  'eephiablaab-chuawiasfoa/instanceHash': 135844746358630959728314799602749985641,
#  'uziiiesfuo-aomaitraeb/inputs/f': 0.6,
#  'ngaiblfrec-psuipoekwei/inputs/state': <everest.builts.states._threshold.Threshold at 0x7f8bcbe5ab00>,
#  'daescbluid-yeaspkruach/inputs/state': <everest.builts.states._threshold.Threshold at 0x7f8bcbff87f0>,
#  'moebleaswua-uakrxeiz/inputs/f': 0.9,
#  'xeoxstiutr-eibroatsuubl/inputs/op': 'ge',
#  'oephaokwaosp-uogloespezh/instanceHash': 36817933487331878618730817125273411850,
#  'dwuiscuikwua-spiopfrikw/inputs/state': <everest.builts.states._threshold.Threshold at 0x7f8bcc0088d0>,
#  'kiaghgruosk-aidrueiutwoe/inputsHash': 113580716987608875754395663156018952936,
#  'pruubpruip-twuefpriasc/inputs/urey': 0.0,
#  'shaadwiupo-jeaphsteapr/outputs/temperatureDotField': array([[[  0.        ],
#          [  0.        ],
#          [  0.        ],
#          ...,
#          [  0.        ],
#          [  0.        ],
#          [  0.        ]],
#
#         [[  0.        ],
#          [ -1.7013452 ],
#          [  0.34080626],
#          ...,
#          [ 12.01165777],
#          [ 20.46379903],
#          [  0.        ]]]),
#  'iuswuithiif-roosckweabl/instanceHash': 107889225614075555620557840279482821097,
#  'chauwskouc-ousfavaang/inputs/f': 0.9,
#  'daescbluid-yeaspkruach/class': planetengine._traverse.Traverse,
#  'kiaghgruosk-aidrueiutwoe/outputs/count': array([1000], dtype=int32),
#  'troarhflux-kwetsskuakw/inputsHash': 10838006864816936863569343237428045938,
#  'laetzgroofl-ngiriobii/instanceHash': 258771918345647684012443960828556666894,
#  'oufriabuigr-spiatwwioch/hashID': 'oufriabuigr-spiatwwioch',
#  'plafruonee-qefleifoa/inputs/temperatureDotField': <ptzvgbfihaqhqzus.py.Constant at 0x7f8bcbe1c400>,
#  'kriobrusmuu-fruetzswuips/inputs/freq': 1.0,
#  'uasfiougroa-aokliitreabl/outputs/count': array([   0, 1000], dtype=int32),
#  'ioklougiest-duangaakwii/traversee': 'auqiuuozau-sweadrpriasw',
#  'thiigriiwiu-psoesnutzeo/inputs/express': True,
#  ...}

# %%
# from planetengine.campaign import Campaign
# mycampaign = Campaign(Isovisc, 2, Ra = [1e4, 1e5], f = [0.5, 0.7])
# mycampaign()
